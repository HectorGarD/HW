# %% [markdown]
# #Librerias

# %%
# Importamos las bibliotecas requeridas.
# !pip install prophet
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from prophet import Prophet
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import matplotlib.dates as mdates
from statsmodels.graphics.tsaplots import month_plot, quarter_plot
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# Requirement already satisfied: prophet in /usr/local/lib/python3.10/dist-packages (1.1.6)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.2.4)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.26.4)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from prophet) (3.8.0)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (2.2.2)
# Requirement already satisfied: holidays<1,>=0.25 in /usr/local/lib/python3.10/dist-packages (from prophet) (0.60)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from prophet) (4.66.6)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from prophet) (6.4.5)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from holidays<1,>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (3.2.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.4->prophet) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.4->prophet) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.16.0)

# %% [markdown]
# Nombre.- Héctor García Domínguez
#
# Matricula.- A01731509

# %% [markdown]
# #Info Inicial

# %%
#Omitamos los Warnings por el momento:
import warnings
warnings.filterwarnings('ignore')

# %%
ticker_symbol = 'NVDA'
#ticker_symbol = 'AAPL'
data = yf.download(ticker_symbol, period='5y')
data.to_csv('historical_data.csv')   # Guardamos los datos

# Eliminar las primeras 2 filas vacías
data = data.iloc[2:]


data = data.reset_index()
data.columns = ['Date', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume']
data['Date'] = pd.to_datetime(data['Date'])
data = data[['Date', 'Adj Close']]
data.set_index('Date', inplace=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                            Adj Close
# Date
# 2019-11-15 00:00:00+00:00   5.080042
# 2019-11-18 00:00:00+00:00   5.281312
# 2019-11-19 00:00:00+00:00   5.174582
# 2019-11-20 00:00:00+00:00   5.253946
# 2019-11-21 00:00:00+00:00   5.229066

# %%
data.index
# Out:
# DatetimeIndex(['2019-11-15 00:00:00+00:00', '2019-11-18 00:00:00+00:00',
#                '2019-11-19 00:00:00+00:00', '2019-11-20 00:00:00+00:00',
#                '2019-11-21 00:00:00+00:00', '2019-11-22 00:00:00+00:00',
#                '2019-11-25 00:00:00+00:00', '2019-11-26 00:00:00+00:00',
#                '2019-11-27 00:00:00+00:00', '2019-11-29 00:00:00+00:00',
#                ...
#                '2024-10-30 00:00:00+00:00', '2024-10-31 00:00:00+00:00',
#                '2024-11-01 00:00:00+00:00', '2024-11-04 00:00:00+00:00',
#                '2024-11-05 00:00:00+00:00', '2024-11-06 00:00:00+00:00',
#                '2024-11-07 00:00:00+00:00', '2024-11-08 00:00:00+00:00',
#                '2024-11-11 00:00:00+00:00', '2024-11-12 00:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='Date', length=1256, freq=None)

# %%
print(data.columns)  # Esto mostrará los nombres de las columnas
print(data.head())   # Para ver las primeras filas del archivo
# Out:
# Index(['Adj Close'], dtype='object')
#                            Adj Close
# Date
# 2019-11-15 00:00:00+00:00   5.080042
# 2019-11-18 00:00:00+00:00   5.281312
# 2019-11-19 00:00:00+00:00   5.174582
# 2019-11-20 00:00:00+00:00   5.253946
# 2019-11-21 00:00:00+00:00   5.229066

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x=data.index, y=data['Adj Close'].squeeze())  # Usar .squeeze() para asegurar que es 1D
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')
plt.title(f'Adjusted Close Price of {ticker_symbol}')
plt.show()

# %% [markdown]
# #Concepto - Adj Close

# %% [markdown]
# Significado de "Adj Close"
#
#
# La columna "Adj Close" (Adjusted Close o Cierre Ajustado) representa el precio de cierre de una acción después de ajustar los eventos corporativos que puedan afectar su valor. Estos ajustes suelen incluir dividendos, divisiones de acciones (splits), emisiones de derechos, y otros eventos similares.
#
# A diferencia del precio de cierre "Close", que refleja el último precio al que se negoció la acción en un día específico, el "Adj Close" ajusta ese valor para que sea más representativo de la rentabilidad real para los accionistas. Esto hace que el "Adj Close" sea particularmente útil en análisis históricos, ya que permite comparar los precios a lo largo del tiempo sin que estos cambios estructurales distorsionen los valores.
#
# Incluir esta explicación en el reporte ayuda a entender por qué el "Adj Close" es más adecuado que el "Close" para estudios de rendimiento a largo plazo, como el análisis de precios históricos de las acciones.

# %% [markdown]
# #Preprocesamiento

# %%
df_temp = data.copy()
df_temp.index = pd.to_datetime(df_temp.index).tz_localize(None)  # Eliminar zona horaria
df_temp.index = df_temp.index.normalize()  # Normalizar
df_temp = df_temp.asfreq('B')
#df_temp = df_temp.rename(columns={"Date": "ds", "Adj Close": "y"})
df_temp = df_temp.fillna(method='ffill')

df_temp.index
# Out:
# DatetimeIndex(['2019-11-15', '2019-11-18', '2019-11-19', '2019-11-20',
#                '2019-11-21', '2019-11-22', '2019-11-25', '2019-11-26',
#                '2019-11-27', '2019-11-28',
#                ...
#                '2024-10-30', '2024-10-31', '2024-11-01', '2024-11-04',
#                '2024-11-05', '2024-11-06', '2024-11-07', '2024-11-08',
#                '2024-11-11', '2024-11-12'],
#               dtype='datetime64[ns]', name='Date', length=1303, freq='B')

# %%
df_temp = df_temp.sort_index()

test_size = 20
test = df_temp.iloc[-test_size:]  # Últimos 20 datos
train = df_temp.iloc[:-test_size]  # Todos los datos anteriores a los últimos 20

print(f'Tamaño del conjunto de entrenamiento: {train.shape}')
print(f'Tamaño del conjunto de prueba: {test.shape}')
# Out:
# Tamaño del conjunto de entrenamiento: (1283, 1)
# Tamaño del conjunto de prueba: (20, 1)

# %%
trainp = train.rename(columns={"Adj Close": "y"})
trainp = trainp.reset_index()
trainp = trainp.rename(columns={"Date": "ds"})

# %%
train.head()
# Out:
#             Adj Close
# Date
# 2019-11-15   5.080042
# 2019-11-18   5.281312
# 2019-11-19   5.174582
# 2019-11-20   5.253946
# 2019-11-21   5.229066

# %%
# Seleccionamos solo la columna "Adj Close"
adj_close_data = data['Adj Close']

# Dividimos los datos: último 20 valores para Test, el resto para Train
train_data = adj_close_data[:-20]
test_data = adj_close_data[-20:]

# Mostramos las dimensiones de cada conjunto para verificar
print(f"Tamaño del conjunto de entrenamiento (Train): {train_data.shape[0]}")
print(f"Tamaño del conjunto de prueba (Test): {test_data.shape[0]}")
# Out:
# Tamaño del conjunto de entrenamiento (Train): 1236
# Tamaño del conjunto de prueba (Test): 20

# %%
train['Adj Close'].plot(title=f'Adjusted Close Price of {ticker_symbol}', style='-b')
plt.show()

# %%
test['Adj Close'].plot(title=f'Adjusted Close Price of {ticker_symbol}', style='-b')
plt.show()

# %% [markdown]
# # #1 Modelo Ingenuo

# %%
test['Adj Close'].values
# Out:
# array([135.72000122, 136.92999268, 138.        , 143.71000671,
#        143.58999634, 139.55999756, 140.41000366, 141.53999329,
#        140.52000427, 141.25      , 139.33999634, 132.75999451,
#        135.3999939 , 136.05000305, 139.91000366, 145.61000061,
#        148.88000488, 147.63000488, 145.25999451, 148.28999329])

# %%
history = [x for x in train['Adj Close'].values]   # Definimos "history" donde de manera incremental se irán agregando registros mensuales.
predictions = list()    # Lista que contendrá las predicciones del modelo ingenuo.

for i in range(len(test['Adj Close'])):
  # Obtenemos las predicciones:
  yhat = history[-1]   # La primera vez, tomamos el último dato del Train, en las siguientes, se van agregando los datos de Test.
  predictions.append(yhat)

  # Observaciones-registros reales:
  obs = test.iloc[i]['Adj Close']   # Ahora vamos tomando los datos de Test.
  history.append(obs)  # Vamos agregando a "history" (que ya tiene todo los de Train) en cada iteración, un dato más de los de Test.
  print('>Esperado-real = %3d, Predicción = %.3f' % (obs, yhat))


# Calculamos la raíz del error cuadrático medio (RMSE):
rmse = np.sqrt(mean_squared_error(test['Adj Close'].values, predictions))
print('\nError-Modelo-Naive: RMSE: %.3f' % rmse)
# Out:
# >Esperado-real = 135, Predicción = 131.600
# >Esperado-real = 136, Predicción = 135.720
# >Esperado-real = 138, Predicción = 136.930
# >Esperado-real = 143, Predicción = 138.000
# >Esperado-real = 143, Predicción = 143.710
# >Esperado-real = 139, Predicción = 143.590
# >Esperado-real = 140, Predicción = 139.560
# >Esperado-real = 141, Predicción = 140.410
# >Esperado-real = 140, Predicción = 141.540
# >Esperado-real = 141, Predicción = 140.520
# >Esperado-real = 139, Predicción = 141.250
# >Esperado-real = 132, Predicción = 139.340
# >Esperado-real = 135, Predicción = 132.760
# >Esperado-real = 136, Predicción = 135.400
# >Esperado-real = 139, Predicción = 136.050
# >Esperado-real = 145, Predicción = 139.910
# >Esperado-real = 148, Predicción = 145.610
# >Esperado-real = 147, Predicción = 148.880
# >Esperado-real = 145, Predicción = 147.630
# >Esperado-real = 148, Predicción = 145.260
#
# Error-Modelo-Naive: RMSE: 3.169

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax = plt.plot(train['Adj Close'], '-k') #Datos de entrenamiento (historicos)
ax = plt.plot(test['Adj Close'], '+b') #Datos de prueba reales (los del ultimo año a predecir)
ax = plt.plot(test.index, predictions, 'xr') #Predicciones del siguiente modelo ingenuo para el ultimo año

# %% [markdown]
# # #2 Modelo Arima

# %%
# Descomposición estacional con periodo de 30 días sin resampleo
decomposition = seasonal_decompose(train['Adj Close'], model='multiplicative', period=30)

fig = decomposition.plot()
fig.set_size_inches(10, 6)
plt.show()

# %%
# Gráfica para detección de estacionalidad mensual:
fig = month_plot(train['Adj Close'].resample('M').mean(), ylabel='$')
fig.set_size_inches(6,6)
plt.show()

# %%
#Gráfica para detección de estacionalidad trimestral:
fig = quarter_plot(train['Adj Close'].resample('Q').mean(), ylabel='$')
fig.set_size_inches(6,6)
plt.show()

# %%
# Gráfico de Autocorrelación (ACF: Auto-Correlation-Function)
fig,ax = plt.subplots(figsize = (6,4))
plot_acf(train['Adj Close'], lags=60, ax=ax)   # Eliges el número de unidades (meses) desfasadas. El número de "lags" es el número
plt.show()                          # que define la partición en el eje horizontal. El área no sombreada nos habla de
                                    # la cantidad de períodos de tiempo hacia atrás cuya información proporcionada es
                                    # significativa para la predicción futura.
                                    # También nos ayuda a detectar periodicidades, como en este caso que se observa a 13 meses, aprox.

# %%
# Gráfico de Autocorrelación Parcial (PACF):
fig, ax = plt.subplots(figsize = (6,4))
plot_pacf(train['Adj Close'], lags = 60, ax = ax, method="ols")   # ols: regression of time series on lags of it an on constant. predetrminado method="ywm"
plt.show()

# %%
# Lo primero es para quitar la estacionalidad y transformar un problema
# de tipo no-estacionario (SARIMA) en uno estacionario (ARIMA):

# Diferencia de datos consecutivos en el tiempo
# y podemos ahora usar ARIMA:
def difference(dataset, interval=1):
  diff = list()

  for i in range(interval, len(dataset)):
    value = dataset[i] - dataset[i - interval]
    diff.append(value)

  return np.array(diff)



# Invierte las diferencias anteriores, es decir, nos regresa la estacionalidad:
def inverse_difference(history, yhat, interval=1):
  return yhat + history[-interval]

# %%
# Definamos la siguiente lista de registros de pasajeros en el tiempo:
history = [x for x in train.loc[:,'Adj Close'].values]   # train-ndarray : columna solo con los registros de pasajeros "y".
                               # history-list : lista con los datos del train.

predictions = list()   # Para incluir las predicciones que vaya generando el modelo.

for i in range(len(test['Adj Close'])):
  #
  days = 12
  diff = difference(history, days)    # diff-list: lista de los datos de diferencias para transformar SARIMA en ARIMA.

  # Generamos el modelo.
  #model = ARIMA(diff, order=(3,0,13),) # Si aplicamos diff, entonces d=0 es aplicable.
  model = ARIMA(diff, order=(1,0,1),)
  model_fit = model.fit(method_kwargs={'maxiter':300})  # Aumentar las iteraciones para evitar el WarningConvergence.

  yhat = model_fit.forecast()[0]   # prediccions (yhat) de cada registro, es un solo número flotante.
  yhat = inverse_difference(history, yhat, days)    # El "history" sigue siendo la lista de arriba.
                                                              # El nuevo "yhat" es cada un nuevo valor (float) de predicción.
  predictions.append(yhat)  # predictions-list : lista que se va incrementando al ir agregando cada predicción nueva.

  # Observaciones-reales:
  obs = test.iloc[i]['Adj Close']   #  cada dato es un flotante.
  history.append(obs)   #  history-list : se va incrementado a partir del Train con los registros-observaciones reales.

  print('>Esperado-real = %3d, Predicción = %.3f' % (obs, yhat))

# Error RMSE:
rmse = np.sqrt(mean_squared_error(test['Adj Close'].values, predictions))
print('\nError-Modelo-ARIMA: RMSE: %.3f' % rmse)
# Out:
# >Esperado-real = 135, Predicción = 131.137
# >Esperado-real = 136, Predicción = 129.826
# >Esperado-real = 138, Predicción = 136.701
# >Esperado-real = 143, Predicción = 140.514
# >Esperado-real = 143, Predicción = 144.024
# >Esperado-real = 139, Predicción = 145.120
# >Esperado-real = 140, Predicción = 144.388
# >Esperado-real = 141, Predicción = 140.000
# >Esperado-real = 140, Predicción = 142.964
# >Esperado-real = 141, Predicción = 140.362
# >Esperado-real = 139, Predicción = 144.028
# >Esperado-real = 132, Predicción = 133.268
# >Esperado-real = 135, Predicción = 136.931
# >Esperado-real = 136, Predicción = 136.867
# >Esperado-real = 139, Predicción = 137.361
# >Esperado-real = 145, Predicción = 145.351
# >Esperado-real = 148, Predicción = 145.416
# >Esperado-real = 147, Predicción = 144.231
# >Esperado-real = 145, Predicción = 147.651
# >Esperado-real = 148, Predicción = 146.300
#
# Error-Modelo-ARIMA: RMSE: 3.197

# %%
fig, ax = plt.subplots(figsize=(10, 4))

ax.plot(train.index, train['Adj Close'], '-k', label='Train')  # Línea negra para los datos de entrenamiento
ax.plot(test.index, test['Adj Close'], '-b', label='Test')  # Línea azul para los datos de prueba
ax.plot(test.index, test['Adj Close'], '+c', label='Test Points')  # Puntos cyan para los datos de prueba

ax.plot(test.index, predictions, 'xr', label='Predictions')  # Cruces rojas para las predicciones

ax.set_title('Gráfico de Datos de Entrenamiento, Prueba y Predicciones')
ax.set_xlabel('Fecha')
ax.set_ylabel('Precio Ajustado de Cierre ($)')

ax.legend()

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))

# Graficar los datos de entrenamiento, prueba y predicciones
ax.plot(train['Adj Close'], 'k-', label='Train')      # Línea negra continua para el entrenamiento
ax.plot(test['Adj Close'], 'b-o', label='Test')        # Línea azul continua para el conjunto de prueba
ax.plot(test.index, predictions, 'r-x', label='Predictions')  # Cruces rojas para las predicciones

last_year = pd.to_datetime('today') - pd.DateOffset(days=60)
ax.set_xlim(last_year, test.index[-1])

ax.set_ylim(100, 150)
# Añadir leyenda y etiquetas de ejes
ax.legend()
ax.set_title('Gráfico de Datos de Entrenamiento, Prueba y Predicciones del Modelo ARIMA: NVIDIA')
ax.set_xlabel('Fecha')
ax.set_ylabel('Precio Ajustado de Cierre')

# Mostrar la gráfica
plt.tight_layout()
plt.show()

# %% [markdown]
# # #3 Modelo Propeth

# %%
train = data.iloc[0:-12,:]
test = data.iloc[-12:,:]

# %%
data.head()
# Out:
#                            Adj Close
# Date
# 2019-11-15 00:00:00+00:00   5.080042
# 2019-11-18 00:00:00+00:00   5.281312
# 2019-11-19 00:00:00+00:00   5.174582
# 2019-11-20 00:00:00+00:00   5.253946
# 2019-11-21 00:00:00+00:00   5.229066

# %%
trainp = train.rename(columns={"Adj Close": "y"})
trainp = trainp.reset_index()
trainp = trainp.rename(columns={"Date": "ds"})
# Convertir la columna 'ds' al formato deseado sin la zona horaria
trainp['ds'] = pd.to_datetime(trainp['ds']).dt.strftime('%Y-%m-%d')  # Cambia el formato a 'YYYY-MM-DD'

# Verifica el cambio
trainp.head()
# Out:
#            ds         y
# 0  2019-11-15  5.080042
# 1  2019-11-18  5.281312
# 2  2019-11-19  5.174582
# 3  2019-11-20  5.253946
# 4  2019-11-21  5.229066

# %%
# Calculamos el error RMSE:

testp = test.rename(columns={"Adj Close": "y"})
testp = testp.reset_index()
testp = testp.rename(columns={"Date": "ds"})
# Cambiar el formato de la columna 'ds' a 'YYYY-MM-DD'
testp['ds'] = testp['ds'].dt.strftime('%Y-%m-%d')
testp
# Out:
#             ds           y
# 0   2024-10-28  140.520004
# 1   2024-10-29  141.250000
# 2   2024-10-30  139.339996
# 3   2024-10-31  132.759995
# 4   2024-11-01  135.399994
# 5   2024-11-04  136.050003
# 6   2024-11-05  139.910004
# 7   2024-11-06  145.610001
# 8   2024-11-07  148.880005
# 9   2024-11-08  147.630005
# 10  2024-11-11  145.259995
# 11  2024-11-12  148.289993

# %%
model = Prophet(
    seasonality_mode='additive',
    yearly_seasonality=False,
    changepoint_prior_scale=0.1,
    seasonality_prior_scale=0.5
)

model.fit(trainp)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp3cyy1t0l/_008dmhk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp3cyy1t0l/wvbvxq26.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87305', 'data', 'file=/tmp/tmp3cyy1t0l/_008dmhk.json', 'init=/tmp/tmp3cyy1t0l/wvbvxq26.json', 'output', 'file=/tmp/tmp3cyy1t0l/prophet_modelbi5m3aj1/prophet_model-20241113055407.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:54:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:54:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
# Calculamos el error RMSE:

pred_FP = model.predict(testp)['yhat']
rmse = np.sqrt(mean_squared_error(testp['y'], pred_FP))
print('\nError-Modelo-FacebookProphet: RMSE: %.3f' % rmse)
# Out:
# Error-Modelo-FacebookProphet: RMSE: 4.399

# %%
trainp['ds'] = pd.to_datetime(trainp['ds']).dt.date
testp['ds'] = pd.to_datetime(testp['ds']).dt.date

# %%
# Predecir con Prophet
forecast = model.predict(testp)

fig = model.plot(forecast)
fig.set_size_inches(10, 5)
ax = fig.gca()

last_year = pd.to_datetime('today') - pd.DateOffset(days=60)
ax.set_xlim(last_year, testp['ds'].max())

ax.set_ylim(100, 150)

ax.plot(trainp['ds'], trainp['y'], 'k-', label='Datos de Entrenamiento (Train)')  # Línea negra continua para los datos de entrenamiento

ax.plot(testp['ds'], testp['y'], 'r-o', label='Datos de Prueba (Test)')

ax.plot(testp['ds'], forecast['yhat'], '+c', label='Predicciones (yhat)')

ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # #4 Modelo LSTM

# %%
df = pd.read_csv('historical_data.csv', skiprows=2)
df = df[['Date', 'Unnamed: 1']]
df.columns = ['ds', 'y']
df['ds'] = pd.to_datetime(df['ds']).dt.normalize().dt.tz_localize(None)
df_mensual = df.resample('M', on='ds').mean().reset_index()
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      1258 non-null   datetime64[ns]
#  1   y       1258 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 19.8 KB
#           ds         y
# 0 2019-11-13  5.189010
# 1 2019-11-14  5.219362
# 2 2019-11-15  5.080042
# 3 2019-11-18  5.281312
# 4 2019-11-19  5.174582

# %%
def preparando_datos(myData, myDate):

  # ********************* Entrenamiento ****************************

  # Los datos de entrenamiento son previos a la fecha "Date" que indiques y
  # tomarán hisotriales en este caso de 12 períodos previos.
  Train_Data = myData['y'][myData['ds'] < myDate].to_numpy()

  periodo = 12   # 12 meses al año

  Data_Train = []
  Data_Train_X = []
  Data_Train_Y = []

  for i in range(0, len(Train_Data), periodo):    # observa que va formando el Train set con historiales de 12 períodos consecutivos.
    try:
      Data_Train.append(Train_Data[i : i + periodo])
    except:
      pass


  # En ocasiones hay datos perdidos, en cuyo caso la última serie
  # de datos la eliminamos:
  if len(Data_Train[-1]) < periodo:
    Data_Train.pop(-1)


  # Hay que darle la forma (dimensionalidad) que requieren los modelos
  # de aprendizaje profundo, en particular la librería de TensorFlow:
  #     (batch_size, sequence_length, input_dimension).

  Data_Train_X = Data_Train[0 : -1]
  Data_Train_X = np.array(Data_Train_X)
  Data_Train_X = Data_Train_X.reshape((-1, periodo, 1))

  Data_Train_Y = Data_Train[1 : len(Data_Train)]
  Data_Train_Y = np.array(Data_Train_Y)
  Data_Train_Y = Data_Train_Y.reshape((-1, periodo, 1))


  # ********************* Testeo ****************************

  # Los datos de prueba (Test) son posteriores a la fecha "Date" y que es el
  # último ciclo que deseas predecir:
  Test_Data = myData['y'][myData['ds'] >= myDate].to_numpy()

  # inicialización de listas:
  Data_Test = []
  Data_Test_X = []
  Data_Test_Y = []

  for i in range(0, len(Test_Data), periodo):
    try:
      Data_Test.append(Test_Data[i : i + periodo])
    except:
      pass


  if len(Data_Test[-1]) < periodo:
    Data_Test.pop(-1)

  Data_Test_X = Data_Test[0 : -1]
  Data_Test_X = np.array(Data_Test_X)
  Data_Test_X = Data_Test_X.reshape((-1, periodo, 1))

  Data_Test_Y = Data_Test[1 : len(Data_Test)]
  Data_Test_Y = np.array(Data_Test_Y)
  Data_Test_Y = Data_Test_Y.reshape((-1, periodo, 1))


  return Data_Train_X, Data_Train_Y, Data_Test_X, Data_Test_Y

# %%
# Get the last date in the DataFrame
last_date = df_mensual['ds'].max()

# Calculate the threshold date as 12 months before the last date
threshold_date = last_date - pd.DateOffset(years = 2)

# Asegúrate de que la columna de fechas del DataFrame sea de tipo DateTime.
# Se generan paquetes de 12 meses. Los *_Y son los años desfasados hacia adelante
# de los *_X:

Train_X, Train_Y, Test_X, Test_Y = preparando_datos(df_mensual, threshold_date)

threshold_date
# Out:
# Timestamp('2022-11-30 00:00:00')

# %%
# Podemos definir la manera en que el tamaño de paso (learning-rate) varíe
# en cada época. Es usual definir también algunas funciones, exponenciales,
# por ejemplo. Por el momento definamos valores constantes por intervalos:

def scheduler(epoch):

  if epoch <= 100:
    lrate = 0.05
  elif epoch <= 180:
    lrate = 0.0005
  elif epoch <=190:
    lrate = 0.00005
  else:
    lrate = (10 ** -5)

  return lrate


callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

# %%
def myModel():

  model = tf.keras.models.Sequential([tf.keras.layers.LSTM(20, input_shape=(12, 1), activation=tf.nn.leaky_relu, return_sequences=False),
                                      tf.keras.layers.BatchNormalization(),
                                      tf.keras.layers.Dropout(0.2),
                                      #tf.keras.layers.LSTM(20, activation=tf.nn.leaky_relu),
                                      #tf.keras.layers.BatchNormalization(),
                                      #tf.keras.layers.Dropout(0.2),

                                      tf.keras.layers.Dense(200, activation=tf.nn.leaky_relu),
                                      tf.keras.layers.Dropout(0.2),
                                      #tf.keras.layers.Dense(120, activation=tf.nn.leaky_relu),


                                      tf.keras.layers.Dense(12, activation=tf.nn.leaky_relu)
                                      ])
  return model


# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++


my_LSTM_model2 = myModel()

my_LSTM_model2.compile(optimizer=tf.keras.optimizers.Adam(),
                      loss='mse',    # función de costo "mse"
                      metrics=[tf.keras.metrics.RootMeanSquaredError()]   #  RMSE- despliega
                      )


H = my_LSTM_model2.fit(Train_X,
                       Train_Y,
                       epochs=200,
                       validation_data=(Test_X, Test_Y),
                       callbacks=[callback],

                       )



N = 50  # Para omitir los N primeros valores en la gráfica, que en ocasiones son
        # demasiado grandes los errores y no dejan apreciar las curvas de aprendizaje.

epochs = range(N+1, len(H.history["loss"]) + 1)

fig, ax2 = plt.subplots()
fig.set_figheight(5)
ax2.plot(epochs, H.history["root_mean_squared_error"][N:], label = "Training Root Mean Squared Error")
ax2.plot(epochs, H.history["val_root_mean_squared_error"][N:], label = "Validation Root Mean Squared Error")
ax2.set(xlabel = "Epochs", ylabel = "Loss-RMSE")
ax2.legend()

plt.show()
# Out:
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - loss: 375.4698 - root_mean_squared_error: 19.3770 - val_loss: 8822.2158 - val_root_mean_squared_error: 93.9267 - learning_rate: 0.0500
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 345.4081 - root_mean_squared_error: 18.5852 - val_loss: 8933.8867 - val_root_mean_squared_error: 94.5192 - learning_rate: 0.0500
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 309.1016 - root_mean_squared_error: 17.5813 - val_loss: 8839.5459 - val_root_mean_squared_error: 94.0189 - learning_rate: 0.0500
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 198.7092 - root_mean_squared_error: 14.0964 - val_loss: 8512.8223 - val_root_mean_squared_error: 92.2650 - learning_rate: 0.0500
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 82.5576 - root_mean_squared_error: 9.0861 - val_loss: 8533.0498 - val_root_mean_squared_error: 92.3745 - learning_rate: 0.0500
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 147.5433 - root_mean_squared_error: 12.1467 - val_loss: 6605914.5000 - val_root_mean_squared_error: 2570.1973 - learning_rate: 0.0500
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 324.5159 - root_mean_squared_error: 18.0143 - val_loss: 183350160.0000 - val_root_mean_squared_error: 13540.6855 - learning_rate: 0.0500
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 172.6698 - root_mean_squared_error: 13.1404 - val_loss: 4528255.0000 - val_root_mean_squared_error: 2127.9697 - learning_rate: 0.0500
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 143.9493 - root_mean_squared_error: 11.9979 - val_loss: 3160513.2500 - val_root_mean_squared_error: 1777.7832 - learning_rate: 0.0500
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 247.4802 - root_mean_squared_error: 15.7315 - val_loss: 1688197.0000 - val_root_mean_squared_error: 1299.3064 - learning_rate: 0.0500
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 53.0408 - root_mean_squared_error: 7.2829 - val_loss: 1726246272.0000 - val_root_mean_squared_error: 41548.1211 - learning_rate: 0.0500
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 60.7121 - root_mean_squared_error: 7.7918 - val_loss: 544382.0625 - val_root_mean_squared_error: 737.8225 - learning_rate: 0.0500
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 53.2006 - root_mean_squared_error: 7.2939 - val_loss: 385057.2812 - val_root_mean_squared_error: 620.5298 - learning_rate: 0.0500
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 51.0998 - root_mean_squared_error: 7.1484 - val_loss: 253464.1406 - val_root_mean_squared_error: 503.4522 - learning_rate: 0.0500
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 102.3825 - root_mean_squared_error: 10.1184 - val_loss: 203409.3281 - val_root_mean_squared_error: 451.0092 - learning_rate: 0.0500
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 61.4082 - root_mean_squared_error: 7.8363 - val_loss: 181506.4531 - val_root_mean_squared_error: 426.0357 - learning_rate: 0.0500
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 152.2516 - root_mean_squared_error: 12.3390 - val_loss: 181132.9844 - val_root_mean_squared_error: 425.5972 - learning_rate: 0.0500
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 29.7287 - root_mean_squared_error: 5.4524 - val_loss: 161634.6094 - val_root_mean_squared_error: 402.0381 - learning_rate: 0.0500
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 43.1093 - root_mean_squared_error: 6.5658 - val_loss: 162519.6406 - val_root_mean_squared_error: 403.1372 - learning_rate: 0.0500
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 18.6562 - root_mean_squared_error: 4.3193 - val_loss: 151096.6094 - val_root_mean_squared_error: 388.7115 - learning_rate: 0.0500
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 23.8345 - root_mean_squared_error: 4.8821 - val_loss: 133730.6250 - val_root_mean_squared_error: 365.6920 - learning_rate: 0.0500
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 52.6865 - root_mean_squared_error: 7.2585 - val_loss: 124258.1250 - val_root_mean_squared_error: 352.5027 - learning_rate: 0.0500
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 50.4918 - root_mean_squared_error: 7.1058 - val_loss: 96152.7891 - val_root_mean_squared_error: 310.0851 - learning_rate: 0.0500
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 28.3560 - root_mean_squared_error: 5.3250 - val_loss: 74673.3359 - val_root_mean_squared_error: 273.2642 - learning_rate: 0.0500
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 15.5583 - root_mean_squared_error: 3.9444 - val_loss: 61309.1523 - val_root_mean_squared_error: 247.6069 - learning_rate: 0.0500
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 11.6632 - root_mean_squared_error: 3.4151 - val_loss: 54645.3438 - val_root_mean_squared_error: 233.7634 - learning_rate: 0.0500
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 8.5443 - root_mean_squared_error: 2.9231 - val_loss: 52681.8789 - val_root_mean_squared_error: 229.5253 - learning_rate: 0.0500
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - loss: 15.9047 - root_mean_squared_error: 3.9881 - val_loss: 43022.3398 - val_root_mean_squared_error: 207.4183 - learning_rate: 0.0500
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 49.9488 - root_mean_squared_error: 7.0674 - val_loss: 39663.8594 - val_root_mean_squared_error: 199.1579 - learning_rate: 0.0500
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 39.5411 - root_mean_squared_error: 6.2882 - val_loss: 41348.2070 - val_root_mean_squared_error: 203.3426 - learning_rate: 0.0500
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 25.9822 - root_mean_squared_error: 5.0973 - val_loss: 42777.0898 - val_root_mean_squared_error: 206.8262 - learning_rate: 0.0500
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 33.6798 - root_mean_squared_error: 5.8034 - val_loss: 43804.7383 - val_root_mean_squared_error: 209.2958 - learning_rate: 0.0500
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 18.3991 - root_mean_squared_error: 4.2894 - val_loss: 42820.5117 - val_root_mean_squared_error: 206.9312 - learning_rate: 0.0500
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 11.0805 - root_mean_squared_error: 3.3287 - val_loss: 40748.4648 - val_root_mean_squared_error: 201.8625 - learning_rate: 0.0500
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 62.0362 - root_mean_squared_error: 7.8763 - val_loss: 27737.0059 - val_root_mean_squared_error: 166.5443 - learning_rate: 0.0500
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 34.1506 - root_mean_squared_error: 5.8438 - val_loss: 14564.5898 - val_root_mean_squared_error: 120.6838 - learning_rate: 0.0500
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 8.0416 - root_mean_squared_error: 2.8358 - val_loss: 7272.0503 - val_root_mean_squared_error: 85.2763 - learning_rate: 0.0500
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 61.3998 - root_mean_squared_error: 7.8358 - val_loss: 4041.9490 - val_root_mean_squared_error: 63.5763 - learning_rate: 0.0500
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 24.8827 - root_mean_squared_error: 4.9883 - val_loss: 3125.5312 - val_root_mean_squared_error: 55.9065 - learning_rate: 0.0500
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 14.0568 - root_mean_squared_error: 3.7492 - val_loss: 2935.8406 - val_root_mean_squared_error: 54.1834 - learning_rate: 0.0500
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 28.2334 - root_mean_squared_error: 5.3135 - val_loss: 3462.3564 - val_root_mean_squared_error: 58.8418 - learning_rate: 0.0500
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 34.2321 - root_mean_squared_error: 5.8508 - val_loss: 4403.3872 - val_root_mean_squared_error: 66.3580 - learning_rate: 0.0500
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 16.5320 - root_mean_squared_error: 4.0660 - val_loss: 5848.0835 - val_root_mean_squared_error: 76.4728 - learning_rate: 0.0500
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 12.0330 - root_mean_squared_error: 3.4689 - val_loss: 7957.9253 - val_root_mean_squared_error: 89.2072 - learning_rate: 0.0500
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 7.1523 - root_mean_squared_error: 2.6744 - val_loss: 10493.8486 - val_root_mean_squared_error: 102.4395 - learning_rate: 0.0500
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - loss: 20.8354 - root_mean_squared_error: 4.5646 - val_loss: 11911.6104 - val_root_mean_squared_error: 109.1403 - learning_rate: 0.0500
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 12.9050 - root_mean_squared_error: 3.5924 - val_loss: 12757.1455 - val_root_mean_squared_error: 112.9475 - learning_rate: 0.0500
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 24.9304 - root_mean_squared_error: 4.9930 - val_loss: 11782.9326 - val_root_mean_squared_error: 108.5492 - learning_rate: 0.0500
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 42.3819 - root_mean_squared_error: 6.5101 - val_loss: 10968.1787 - val_root_mean_squared_error: 104.7291 - learning_rate: 0.0500
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 16.5716 - root_mean_squared_error: 4.0708 - val_loss: 9608.8018 - val_root_mean_squared_error: 98.0245 - learning_rate: 0.0500
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 16.9591 - root_mean_squared_error: 4.1181 - val_loss: 8124.9038 - val_root_mean_squared_error: 90.1382 - learning_rate: 0.0500
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 11.9268 - root_mean_squared_error: 3.4535 - val_loss: 6933.3472 - val_root_mean_squared_error: 83.2667 - learning_rate: 0.0500
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 4.4940 - root_mean_squared_error: 2.1199 - val_loss: 5900.2417 - val_root_mean_squared_error: 76.8130 - learning_rate: 0.0500
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 7.1926 - root_mean_squared_error: 2.6819 - val_loss: 5128.0757 - val_root_mean_squared_error: 71.6106 - learning_rate: 0.0500
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.6300 - root_mean_squared_error: 1.2767 - val_loss: 4528.5122 - val_root_mean_squared_error: 67.2942 - learning_rate: 0.0500
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 4.3845 - root_mean_squared_error: 2.0939 - val_loss: 4107.6030 - val_root_mean_squared_error: 64.0906 - learning_rate: 0.0500
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 4.0854 - root_mean_squared_error: 2.0212 - val_loss: 3912.3020 - val_root_mean_squared_error: 62.5484 - learning_rate: 0.0500
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 5.4509 - root_mean_squared_error: 2.3347 - val_loss: 3767.6375 - val_root_mean_squared_error: 61.3811 - learning_rate: 0.0500
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 15.3632 - root_mean_squared_error: 3.9196 - val_loss: 3677.9570 - val_root_mean_squared_error: 60.6462 - learning_rate: 0.0500
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.8750 - root_mean_squared_error: 1.3693 - val_loss: 3656.2463 - val_root_mean_squared_error: 60.4669 - learning_rate: 0.0500
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 4.6295 - root_mean_squared_error: 2.1516 - val_loss: 3734.9270 - val_root_mean_squared_error: 61.1140 - learning_rate: 0.0500
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 43.8878 - root_mean_squared_error: 6.6248 - val_loss: 3873.7283 - val_root_mean_squared_error: 62.2393 - learning_rate: 0.0500
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 4.0237 - root_mean_squared_error: 2.0059 - val_loss: 4057.0469 - val_root_mean_squared_error: 63.6950 - learning_rate: 0.0500
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 48.8775 - root_mean_squared_error: 6.9912 - val_loss: 4274.0347 - val_root_mean_squared_error: 65.3761 - learning_rate: 0.0500
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 5.9703 - root_mean_squared_error: 2.4434 - val_loss: 4486.4937 - val_root_mean_squared_error: 66.9813 - learning_rate: 0.0500
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 3.2955 - root_mean_squared_error: 1.8153 - val_loss: 4671.9224 - val_root_mean_squared_error: 68.3515 - learning_rate: 0.0500
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 2.8882 - root_mean_squared_error: 1.6995 - val_loss: 4810.3433 - val_root_mean_squared_error: 69.3566 - learning_rate: 0.0500
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.4100 - root_mean_squared_error: 1.1874 - val_loss: 4933.4712 - val_root_mean_squared_error: 70.2387 - learning_rate: 0.0500
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 13.4283 - root_mean_squared_error: 3.6645 - val_loss: 5059.6997 - val_root_mean_squared_error: 71.1316 - learning_rate: 0.0500
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 3.0473 - root_mean_squared_error: 1.7457 - val_loss: 5170.2222 - val_root_mean_squared_error: 71.9043 - learning_rate: 0.0500
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 4.5498 - root_mean_squared_error: 2.1330 - val_loss: 5193.0864 - val_root_mean_squared_error: 72.0631 - learning_rate: 0.0500
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 4.5608 - root_mean_squared_error: 2.1356 - val_loss: 5177.2490 - val_root_mean_squared_error: 71.9531 - learning_rate: 0.0500
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 1.6554 - root_mean_squared_error: 1.2866 - val_loss: 5150.3950 - val_root_mean_squared_error: 71.7663 - learning_rate: 0.0500
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 2.2251 - root_mean_squared_error: 1.4917 - val_loss: 5094.7964 - val_root_mean_squared_error: 71.3778 - learning_rate: 0.0500
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 3.5723 - root_mean_squared_error: 1.8900 - val_loss: 5032.8999 - val_root_mean_squared_error: 70.9429 - learning_rate: 0.0500
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 4.6134 - root_mean_squared_error: 2.1479 - val_loss: 4951.6694 - val_root_mean_squared_error: 70.3681 - learning_rate: 0.0500
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.5036 - root_mean_squared_error: 0.7096 - val_loss: 4886.1064 - val_root_mean_squared_error: 69.9007 - learning_rate: 0.0500
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 2.2446 - root_mean_squared_error: 1.4982 - val_loss: 4778.4321 - val_root_mean_squared_error: 69.1262 - learning_rate: 0.0500
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 2.5814 - root_mean_squared_error: 1.6067 - val_loss: 4651.7051 - val_root_mean_squared_error: 68.2034 - learning_rate: 0.0500
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 2.2624 - root_mean_squared_error: 1.5041 - val_loss: 4499.1011 - val_root_mean_squared_error: 67.0753 - learning_rate: 0.0500
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 1.4835 - root_mean_squared_error: 1.2180 - val_loss: 4388.6680 - val_root_mean_squared_error: 66.2470 - learning_rate: 0.0500
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 3.3275 - root_mean_squared_error: 1.8241 - val_loss: 4385.3496 - val_root_mean_squared_error: 66.2220 - learning_rate: 0.0500
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 1.6973 - root_mean_squared_error: 1.3028 - val_loss: 4421.1792 - val_root_mean_squared_error: 66.4920 - learning_rate: 0.0500
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 6.1965 - root_mean_squared_error: 2.4893 - val_loss: 4423.7500 - val_root_mean_squared_error: 66.5113 - learning_rate: 0.0500
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 6.7939 - root_mean_squared_error: 2.6065 - val_loss: 4458.8384 - val_root_mean_squared_error: 66.7745 - learning_rate: 0.0500
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 3.1413 - root_mean_squared_error: 1.7724 - val_loss: 4484.5415 - val_root_mean_squared_error: 66.9667 - learning_rate: 0.0500
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 9.3157 - root_mean_squared_error: 3.0522 - val_loss: 4391.7876 - val_root_mean_squared_error: 66.2706 - learning_rate: 0.0500
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.8078 - root_mean_squared_error: 0.8988 - val_loss: 4321.8745 - val_root_mean_squared_error: 65.7410 - learning_rate: 0.0500
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 1.7285 - root_mean_squared_error: 1.3147 - val_loss: 4272.7075 - val_root_mean_squared_error: 65.3660 - learning_rate: 0.0500
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 7.9373 - root_mean_squared_error: 2.8173 - val_loss: 4341.9131 - val_root_mean_squared_error: 65.8932 - learning_rate: 0.0500
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 2.3094 - root_mean_squared_error: 1.5197 - val_loss: 4403.9873 - val_root_mean_squared_error: 66.3625 - learning_rate: 0.0500
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 4.9497 - root_mean_squared_error: 2.2248 - val_loss: 4515.4180 - val_root_mean_squared_error: 67.1969 - learning_rate: 0.0500
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 12.4974 - root_mean_squared_error: 3.5352 - val_loss: 4768.6040 - val_root_mean_squared_error: 69.0551 - learning_rate: 0.0500
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 6.4176 - root_mean_squared_error: 2.5333 - val_loss: 4909.5933 - val_root_mean_squared_error: 70.0685 - learning_rate: 0.0500
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 8.8273 - root_mean_squared_error: 2.9711 - val_loss: 5107.5093 - val_root_mean_squared_error: 71.4668 - learning_rate: 0.0500
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 1.2279 - root_mean_squared_error: 1.1081 - val_loss: 5314.3638 - val_root_mean_squared_error: 72.8997 - learning_rate: 0.0500
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 9.0695 - root_mean_squared_error: 3.0116 - val_loss: 5443.9390 - val_root_mean_squared_error: 73.7831 - learning_rate: 0.0500
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 8.3309 - root_mean_squared_error: 2.8863 - val_loss: 5464.4907 - val_root_mean_squared_error: 73.9222 - learning_rate: 0.0500
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 7.8588 - root_mean_squared_error: 2.8034 - val_loss: 5369.4839 - val_root_mean_squared_error: 73.2768 - learning_rate: 0.0500
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 2.9843 - root_mean_squared_error: 1.7275 - val_loss: 5292.4985 - val_root_mean_squared_error: 72.7496 - learning_rate: 0.0500
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 6.7125 - root_mean_squared_error: 2.5908 - val_loss: 5086.7207 - val_root_mean_squared_error: 71.3213 - learning_rate: 0.0500
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 8.1298 - root_mean_squared_error: 2.8513 - val_loss: 5090.4707 - val_root_mean_squared_error: 71.3475 - learning_rate: 5.0000e-04
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 3.1738 - root_mean_squared_error: 1.7815 - val_loss: 5094.9673 - val_root_mean_squared_error: 71.3790 - learning_rate: 5.0000e-04
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 4.1760 - root_mean_squared_error: 2.0435 - val_loss: 5099.8735 - val_root_mean_squared_error: 71.4134 - learning_rate: 5.0000e-04
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 7.9637 - root_mean_squared_error: 2.8220 - val_loss: 5106.4819 - val_root_mean_squared_error: 71.4597 - learning_rate: 5.0000e-04
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 1.9705 - root_mean_squared_error: 1.4037 - val_loss: 5113.4849 - val_root_mean_squared_error: 71.5086 - learning_rate: 5.0000e-04
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8786 - root_mean_squared_error: 1.3706 - val_loss: 5120.3745 - val_root_mean_squared_error: 71.5568 - learning_rate: 5.0000e-04
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 9.4756 - root_mean_squared_error: 3.0782 - val_loss: 5127.4180 - val_root_mean_squared_error: 71.6060 - learning_rate: 5.0000e-04
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 24.3330 - root_mean_squared_error: 4.9328 - val_loss: 5135.4116 - val_root_mean_squared_error: 71.6618 - learning_rate: 5.0000e-04
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 13.5918 - root_mean_squared_error: 3.6867 - val_loss: 5144.3062 - val_root_mean_squared_error: 71.7238 - learning_rate: 5.0000e-04
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 7.0539 - root_mean_squared_error: 2.6559 - val_loss: 5154.3486 - val_root_mean_squared_error: 71.7938 - learning_rate: 5.0000e-04
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 8.9125 - root_mean_squared_error: 2.9854 - val_loss: 5165.1606 - val_root_mean_squared_error: 71.8690 - learning_rate: 5.0000e-04
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 7.3476 - root_mean_squared_error: 2.7106 - val_loss: 5175.5884 - val_root_mean_squared_error: 71.9416 - learning_rate: 5.0000e-04
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.6652 - root_mean_squared_error: 0.8156 - val_loss: 5185.8276 - val_root_mean_squared_error: 72.0127 - learning_rate: 5.0000e-04
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 4.9403 - root_mean_squared_error: 2.2227 - val_loss: 5195.4468 - val_root_mean_squared_error: 72.0794 - learning_rate: 5.0000e-04
# Epoch 116/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 2.3393 - root_mean_squared_error: 1.5295 - val_loss: 5205.4536 - val_root_mean_squared_error: 72.1488 - learning_rate: 5.0000e-04
# Epoch 117/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 7.5350 - root_mean_squared_error: 2.7450 - val_loss: 5216.3086 - val_root_mean_squared_error: 72.2240 - learning_rate: 5.0000e-04
# Epoch 118/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 15.7209 - root_mean_squared_error: 3.9650 - val_loss: 5225.9546 - val_root_mean_squared_error: 72.2908 - learning_rate: 5.0000e-04
# Epoch 119/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 2.2498 - root_mean_squared_error: 1.4999 - val_loss: 5236.1128 - val_root_mean_squared_error: 72.3610 - learning_rate: 5.0000e-04
# Epoch 120/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.9364 - root_mean_squared_error: 0.9677 - val_loss: 5246.1113 - val_root_mean_squared_error: 72.4300 - learning_rate: 5.0000e-04
# Epoch 121/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 14.1251 - root_mean_squared_error: 3.7583 - val_loss: 5254.8706 - val_root_mean_squared_error: 72.4905 - learning_rate: 5.0000e-04
# Epoch 122/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 4.9333 - root_mean_squared_error: 2.2211 - val_loss: 5264.0239 - val_root_mean_squared_error: 72.5536 - learning_rate: 5.0000e-04
# Epoch 123/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 3.0437 - root_mean_squared_error: 1.7446 - val_loss: 5272.8384 - val_root_mean_squared_error: 72.6143 - learning_rate: 5.0000e-04
# Epoch 124/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 6.8376 - root_mean_squared_error: 2.6149 - val_loss: 5282.4419 - val_root_mean_squared_error: 72.6804 - learning_rate: 5.0000e-04
# Epoch 125/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 3.1529 - root_mean_squared_error: 1.7757 - val_loss: 5291.5039 - val_root_mean_squared_error: 72.7427 - learning_rate: 5.0000e-04
# Epoch 126/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 2.1445 - root_mean_squared_error: 1.4644 - val_loss: 5299.9956 - val_root_mean_squared_error: 72.8011 - learning_rate: 5.0000e-04
# Epoch 127/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 3.3028 - root_mean_squared_error: 1.8174 - val_loss: 5308.3027 - val_root_mean_squared_error: 72.8581 - learning_rate: 5.0000e-04
# Epoch 128/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 2.5829 - root_mean_squared_error: 1.6071 - val_loss: 5315.8550 - val_root_mean_squared_error: 72.9099 - learning_rate: 5.0000e-04
# Epoch 129/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 10.0159 - root_mean_squared_error: 3.1648 - val_loss: 5324.3247 - val_root_mean_squared_error: 72.9680 - learning_rate: 5.0000e-04
# Epoch 130/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 3.3018 - root_mean_squared_error: 1.8171 - val_loss: 5332.2656 - val_root_mean_squared_error: 73.0224 - learning_rate: 5.0000e-04
# Epoch 131/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 9.8780 - root_mean_squared_error: 3.1429 - val_loss: 5341.0522 - val_root_mean_squared_error: 73.0825 - learning_rate: 5.0000e-04
# Epoch 132/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 4.1390 - root_mean_squared_error: 2.0345 - val_loss: 5350.0103 - val_root_mean_squared_error: 73.1438 - learning_rate: 5.0000e-04
# Epoch 133/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 1.4373 - root_mean_squared_error: 1.1989 - val_loss: 5359.2988 - val_root_mean_squared_error: 73.2072 - learning_rate: 5.0000e-04
# Epoch 134/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 12.3918 - root_mean_squared_error: 3.5202 - val_loss: 5367.7710 - val_root_mean_squared_error: 73.2651 - learning_rate: 5.0000e-04
# Epoch 135/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 2.1788 - root_mean_squared_error: 1.4761 - val_loss: 5375.9497 - val_root_mean_squared_error: 73.3209 - learning_rate: 5.0000e-04
# Epoch 136/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 7.5717 - root_mean_squared_error: 2.7517 - val_loss: 5383.1255 - val_root_mean_squared_error: 73.3698 - learning_rate: 5.0000e-04
# Epoch 137/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 1.2177 - root_mean_squared_error: 1.1035 - val_loss: 5389.7334 - val_root_mean_squared_error: 73.4148 - learning_rate: 5.0000e-04
# Epoch 138/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 3.3145 - root_mean_squared_error: 1.8206 - val_loss: 5395.6001 - val_root_mean_squared_error: 73.4548 - learning_rate: 5.0000e-04
# Epoch 139/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 5.5741 - root_mean_squared_error: 2.3610 - val_loss: 5401.0630 - val_root_mean_squared_error: 73.4919 - learning_rate: 5.0000e-04
# Epoch 140/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 4.7683 - root_mean_squared_error: 2.1836 - val_loss: 5407.2534 - val_root_mean_squared_error: 73.5340 - learning_rate: 5.0000e-04
# Epoch 141/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 1.6867 - root_mean_squared_error: 1.2987 - val_loss: 5413.9985 - val_root_mean_squared_error: 73.5799 - learning_rate: 5.0000e-04
# Epoch 142/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2.9991 - root_mean_squared_error: 1.7318 - val_loss: 5421.5811 - val_root_mean_squared_error: 73.6314 - learning_rate: 5.0000e-04
# Epoch 143/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 16.3723 - root_mean_squared_error: 4.0463 - val_loss: 5428.3032 - val_root_mean_squared_error: 73.6770 - learning_rate: 5.0000e-04
# Epoch 144/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 8.4148 - root_mean_squared_error: 2.9008 - val_loss: 5434.1362 - val_root_mean_squared_error: 73.7166 - learning_rate: 5.0000e-04
# Epoch 145/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 6.3241 - root_mean_squared_error: 2.5148 - val_loss: 5441.0815 - val_root_mean_squared_error: 73.7637 - learning_rate: 5.0000e-04
# Epoch 146/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 1.7896 - root_mean_squared_error: 1.3378 - val_loss: 5447.7671 - val_root_mean_squared_error: 73.8090 - learning_rate: 5.0000e-04
# Epoch 147/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 6.7741 - root_mean_squared_error: 2.6027 - val_loss: 5453.0122 - val_root_mean_squared_error: 73.8445 - learning_rate: 5.0000e-04
# Epoch 148/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 12.1557 - root_mean_squared_error: 3.4865 - val_loss: 5457.4868 - val_root_mean_squared_error: 73.8748 - learning_rate: 5.0000e-04
# Epoch 149/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 2.9475 - root_mean_squared_error: 1.7168 - val_loss: 5461.6587 - val_root_mean_squared_error: 73.9030 - learning_rate: 5.0000e-04
# Epoch 150/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 5.8821 - root_mean_squared_error: 2.4253 - val_loss: 5466.8979 - val_root_mean_squared_error: 73.9385 - learning_rate: 5.0000e-04
# Epoch 151/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 3.4978 - root_mean_squared_error: 1.8702 - val_loss: 5472.0142 - val_root_mean_squared_error: 73.9731 - learning_rate: 5.0000e-04
# Epoch 152/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 8.4890 - root_mean_squared_error: 2.9136 - val_loss: 5478.8872 - val_root_mean_squared_error: 74.0195 - learning_rate: 5.0000e-04
# Epoch 153/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 1.5763 - root_mean_squared_error: 1.2555 - val_loss: 5486.0859 - val_root_mean_squared_error: 74.0681 - learning_rate: 5.0000e-04
# Epoch 154/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 3.4570 - root_mean_squared_error: 1.8593 - val_loss: 5494.2227 - val_root_mean_squared_error: 74.1230 - learning_rate: 5.0000e-04
# Epoch 155/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 2.3358 - root_mean_squared_error: 1.5283 - val_loss: 5501.8691 - val_root_mean_squared_error: 74.1746 - learning_rate: 5.0000e-04
# Epoch 156/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.7444 - root_mean_squared_error: 1.3207 - val_loss: 5509.6147 - val_root_mean_squared_error: 74.2268 - learning_rate: 5.0000e-04
# Epoch 157/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 7.2288 - root_mean_squared_error: 2.6887 - val_loss: 5517.9712 - val_root_mean_squared_error: 74.2831 - learning_rate: 5.0000e-04
# Epoch 158/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 4.7387 - root_mean_squared_error: 2.1769 - val_loss: 5527.2388 - val_root_mean_squared_error: 74.3454 - learning_rate: 5.0000e-04
# Epoch 159/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 2.7530 - root_mean_squared_error: 1.6592 - val_loss: 5535.9546 - val_root_mean_squared_error: 74.4040 - learning_rate: 5.0000e-04
# Epoch 160/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 7.3435 - root_mean_squared_error: 2.7099 - val_loss: 5543.4082 - val_root_mean_squared_error: 74.4541 - learning_rate: 5.0000e-04
# Epoch 161/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 6.1301 - root_mean_squared_error: 2.4759 - val_loss: 5550.0962 - val_root_mean_squared_error: 74.4990 - learning_rate: 5.0000e-04
# Epoch 162/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 6.9753 - root_mean_squared_error: 2.6411 - val_loss: 5555.6641 - val_root_mean_squared_error: 74.5363 - learning_rate: 5.0000e-04
# Epoch 163/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 1.4860 - root_mean_squared_error: 1.2190 - val_loss: 5561.4712 - val_root_mean_squared_error: 74.5753 - learning_rate: 5.0000e-04
# Epoch 164/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 6.5938 - root_mean_squared_error: 2.5678 - val_loss: 5568.2207 - val_root_mean_squared_error: 74.6205 - learning_rate: 5.0000e-04
# Epoch 165/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 4.0743 - root_mean_squared_error: 2.0185 - val_loss: 5573.7183 - val_root_mean_squared_error: 74.6573 - learning_rate: 5.0000e-04
# Epoch 166/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 1.8805 - root_mean_squared_error: 1.3713 - val_loss: 5578.7280 - val_root_mean_squared_error: 74.6909 - learning_rate: 5.0000e-04
# Epoch 167/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 2.9284 - root_mean_squared_error: 1.7113 - val_loss: 5583.2598 - val_root_mean_squared_error: 74.7212 - learning_rate: 5.0000e-04
# Epoch 168/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 1.2107 - root_mean_squared_error: 1.1003 - val_loss: 5587.9370 - val_root_mean_squared_error: 74.7525 - learning_rate: 5.0000e-04
# Epoch 169/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 8.3909 - root_mean_squared_error: 2.8967 - val_loss: 5592.0249 - val_root_mean_squared_error: 74.7798 - learning_rate: 5.0000e-04
# Epoch 170/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.8837 - root_mean_squared_error: 1.3725 - val_loss: 5596.8320 - val_root_mean_squared_error: 74.8120 - learning_rate: 5.0000e-04
# Epoch 171/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 5.1609 - root_mean_squared_error: 2.2718 - val_loss: 5601.8789 - val_root_mean_squared_error: 74.8457 - learning_rate: 5.0000e-04
# Epoch 172/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 2.6617 - root_mean_squared_error: 1.6315 - val_loss: 5606.6685 - val_root_mean_squared_error: 74.8777 - learning_rate: 5.0000e-04
# Epoch 173/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 3.3627 - root_mean_squared_error: 1.8338 - val_loss: 5610.7090 - val_root_mean_squared_error: 74.9047 - learning_rate: 5.0000e-04
# Epoch 174/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 1.7948 - root_mean_squared_error: 1.3397 - val_loss: 5615.6050 - val_root_mean_squared_error: 74.9373 - learning_rate: 5.0000e-04
# Epoch 175/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 5.9193 - root_mean_squared_error: 2.4330 - val_loss: 5621.8032 - val_root_mean_squared_error: 74.9787 - learning_rate: 5.0000e-04
# Epoch 176/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 4.3981 - root_mean_squared_error: 2.0972 - val_loss: 5627.0991 - val_root_mean_squared_error: 75.0140 - learning_rate: 5.0000e-04
# Epoch 177/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 5.5374 - root_mean_squared_error: 2.3532 - val_loss: 5631.7578 - val_root_mean_squared_error: 75.0450 - learning_rate: 5.0000e-04
# Epoch 178/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 1.2605 - root_mean_squared_error: 1.1227 - val_loss: 5636.5552 - val_root_mean_squared_error: 75.0770 - learning_rate: 5.0000e-04
# Epoch 179/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 9.5032 - root_mean_squared_error: 3.0827 - val_loss: 5640.1797 - val_root_mean_squared_error: 75.1011 - learning_rate: 5.0000e-04
# Epoch 180/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 1.3619 - root_mean_squared_error: 1.1670 - val_loss: 5643.8828 - val_root_mean_squared_error: 75.1258 - learning_rate: 5.0000e-04
# Epoch 181/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 4.0114 - root_mean_squared_error: 2.0028 - val_loss: 5648.7183 - val_root_mean_squared_error: 75.1580 - learning_rate: 5.0000e-04
# Epoch 182/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 1.6010 - root_mean_squared_error: 1.2653 - val_loss: 5652.8745 - val_root_mean_squared_error: 75.1856 - learning_rate: 5.0000e-05
# Epoch 183/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 17.1182 - root_mean_squared_error: 4.1374 - val_loss: 5656.8750 - val_root_mean_squared_error: 75.2122 - learning_rate: 5.0000e-05
# Epoch 184/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 14.4387 - root_mean_squared_error: 3.7998 - val_loss: 5660.9043 - val_root_mean_squared_error: 75.2390 - learning_rate: 5.0000e-05
# Epoch 185/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 5.9107 - root_mean_squared_error: 2.4312 - val_loss: 5664.8198 - val_root_mean_squared_error: 75.2650 - learning_rate: 5.0000e-05
# Epoch 186/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 2.8885 - root_mean_squared_error: 1.6996 - val_loss: 5668.7407 - val_root_mean_squared_error: 75.2910 - learning_rate: 5.0000e-05
# Epoch 187/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 9.9376 - root_mean_squared_error: 3.1524 - val_loss: 5672.5391 - val_root_mean_squared_error: 75.3163 - learning_rate: 5.0000e-05
# Epoch 188/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 4.1173 - root_mean_squared_error: 2.0291 - val_loss: 5676.4360 - val_root_mean_squared_error: 75.3421 - learning_rate: 5.0000e-05
# Epoch 189/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 2.8938 - root_mean_squared_error: 1.7011 - val_loss: 5680.2422 - val_root_mean_squared_error: 75.3674 - learning_rate: 5.0000e-05
# Epoch 190/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 3.6206 - root_mean_squared_error: 1.9028 - val_loss: 5683.9614 - val_root_mean_squared_error: 75.3921 - learning_rate: 5.0000e-05
# Epoch 191/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.9246 - root_mean_squared_error: 0.9616 - val_loss: 5687.6772 - val_root_mean_squared_error: 75.4167 - learning_rate: 5.0000e-05
# Epoch 192/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 1.4111 - root_mean_squared_error: 1.1879 - val_loss: 5691.3931 - val_root_mean_squared_error: 75.4413 - learning_rate: 1.0000e-05
# Epoch 193/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 2.6159 - root_mean_squared_error: 1.6174 - val_loss: 5695.0669 - val_root_mean_squared_error: 75.4657 - learning_rate: 1.0000e-05
# Epoch 194/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 12.0668 - root_mean_squared_error: 3.4737 - val_loss: 5698.7163 - val_root_mean_squared_error: 75.4898 - learning_rate: 1.0000e-05
# Epoch 195/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 5.3204 - root_mean_squared_error: 2.3066 - val_loss: 5702.3179 - val_root_mean_squared_error: 75.5137 - learning_rate: 1.0000e-05
# Epoch 196/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 3.8491 - root_mean_squared_error: 1.9619 - val_loss: 5705.8413 - val_root_mean_squared_error: 75.5370 - learning_rate: 1.0000e-05
# Epoch 197/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 15.1544 - root_mean_squared_error: 3.8929 - val_loss: 5709.3540 - val_root_mean_squared_error: 75.5603 - learning_rate: 1.0000e-05
# Epoch 198/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 1.6236 - root_mean_squared_error: 1.2742 - val_loss: 5712.8335 - val_root_mean_squared_error: 75.5833 - learning_rate: 1.0000e-05
# Epoch 199/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 4.1346 - root_mean_squared_error: 2.0334 - val_loss: 5716.2793 - val_root_mean_squared_error: 75.6061 - learning_rate: 1.0000e-05
# Epoch 200/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 3.3024 - root_mean_squared_error: 1.8173 - val_loss: 5719.6470 - val_root_mean_squared_error: 75.6283 - learning_rate: 1.0000e-05

# %%
# Función para preparar datos
def preparando_datos(myData, myDate, periodo=30):  # ahora periodo es en días
    # Datos de entrenamiento: todos los registros previos a myDate
    Train_Data = myData['y'][myData['ds'] < myDate].to_numpy()

    Data_Train = []
    Data_Train_X = []
    Data_Train_Y = []

    for i in range(0, len(Train_Data), periodo):
        try:
            Data_Train.append(Train_Data[i : i + periodo])
        except:
            pass

    # Eliminación de series incompletas
    if len(Data_Train[-1]) < periodo:
        Data_Train.pop(-1)

    # Dar forma para entrenamiento
    Data_Train_X = Data_Train[0 : -1]
    Data_Train_X = np.array(Data_Train_X)
    Data_Train_X = Data_Train_X.reshape((-1, periodo, 1))

    Data_Train_Y = Data_Train[1 : len(Data_Train)]
    Data_Train_Y = np.array(Data_Train_Y)
    Data_Train_Y = Data_Train_Y.reshape((-1, periodo, 1))

    # Datos de prueba (test)
    Test_Data = myData['y'][myData['ds'] >= myDate].to_numpy()

    Data_Test = []
    Data_Test_X = []
    Data_Test_Y = []

    for i in range(0, len(Test_Data), periodo):
        try:
            Data_Test.append(Test_Data[i : i + periodo])
        except:
            pass

    if len(Data_Test[-1]) < periodo:
        Data_Test.pop(-1)

    Data_Test_X = Data_Test[0 : -1]
    Data_Test_X = np.array(Data_Test_X)
    Data_Test_X = Data_Test_X.reshape((-1, periodo, 1))

    Data_Test_Y = Data_Test[1 : len(Data_Test)]
    Data_Test_Y = np.array(Data_Test_Y)
    Data_Test_Y = Data_Test_Y.reshape((-1, periodo, 1))

    return Data_Train_X, Data_Train_Y, Data_Test_X, Data_Test_Y

# Definir última fecha y calcular umbral en días
last_date = df['ds'].max()
threshold_date = last_date - pd.DateOffset(months=6)  # Ejemplo: 6 meses atrás

# Preparar datos para entrenamiento y prueba
Train_X, Train_Y, Test_X, Test_Y = preparando_datos(df, threshold_date, periodo=30)

# Definición del modelo LSTM
def myModel():
    model = tf.keras.models.Sequential([
        tf.keras.layers.LSTM(20, input_shape=(30, 1), activation=tf.nn.leaky_relu, return_sequences=False),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(200, activation=tf.nn.leaky_relu),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(30, activation=tf.nn.leaky_relu)
    ])
    return model

# Compilación y entrenamiento del modelo
my_LSTM_model = myModel()
my_LSTM_model.compile(optimizer=tf.keras.optimizers.Adam(),
                      loss='mse',
                      metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Definición de la función de ajuste de tasa de aprendizaje
def scheduler(epoch):
    if epoch <= 100:
        lrate = 0.05
    elif epoch <= 180:
        lrate = 0.0005
    elif epoch <= 190:
        lrate = 0.00005
    else:
        lrate = (10 ** -5)
    return lrate

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

# Entrenamiento del modelo
H = my_LSTM_model.fit(Train_X, Train_Y, epochs=200, validation_data=(Test_X, Test_Y), callbacks=[callback])

# Visualización del error RMSE
N = 50  # omitir los primeros 50 valores
epochs = range(N+1, len(H.history["loss"]) + 1)

plt.figure(figsize=(10, 5))
plt.plot(epochs, H.history["root_mean_squared_error"][N:], label="Training RMSE")
plt.plot(epochs, H.history["val_root_mean_squared_error"][N:], label="Validation RMSE")
plt.xlabel("Epochs")
plt.ylabel("Loss-RMSE")
plt.legend()
plt.show()
# Out:
# Epoch 1/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 48s 334ms/step - loss: 931.1818 - root_mean_squared_error: 30.5109 - val_loss: 6202.7847 - val_root_mean_squared_error: 78.7578 - learning_rate: 0.0500
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 626.5203 - root_mean_squared_error: 25.0258 - val_loss: 6843.8130 - val_root_mean_squared_error: 82.7273 - learning_rate: 0.0500
# Epoch 3/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 438.0885 - root_mean_squared_error: 20.9301 - val_loss: 1352.4391 - val_root_mean_squared_error: 36.7755 - learning_rate: 0.0500
# Epoch 4/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 210.0896 - root_mean_squared_error: 14.4936 - val_loss: 583.3963 - val_root_mean_squared_error: 24.1536 - learning_rate: 0.0500
# Epoch 5/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 120.5681 - root_mean_squared_error: 10.9803 - val_loss: 1392.4857 - val_root_mean_squared_error: 37.3160 - learning_rate: 0.0500
# Epoch 6/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 226.7787 - root_mean_squared_error: 15.0590 - val_loss: 2516.0291 - val_root_mean_squared_error: 50.1600 - learning_rate: 0.0500
# Epoch 7/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 104.0469 - root_mean_squared_error: 10.2003 - val_loss: 3498.7305 - val_root_mean_squared_error: 59.1501 - learning_rate: 0.0500
# Epoch 8/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 147.0211 - root_mean_squared_error: 11.9342 - val_loss: 3163.8352 - val_root_mean_squared_error: 56.2480 - learning_rate: 0.0500
# Epoch 9/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 58.2103 - root_mean_squared_error: 7.6283 - val_loss: 1865.9883 - val_root_mean_squared_error: 43.1971 - learning_rate: 0.0500
# Epoch 10/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 161.1344 - root_mean_squared_error: 12.6911 - val_loss: 808.7488 - val_root_mean_squared_error: 28.4385 - learning_rate: 0.0500
# Epoch 11/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 86.4814 - root_mean_squared_error: 9.2935 - val_loss: 397.5548 - val_root_mean_squared_error: 19.9388 - learning_rate: 0.0500
# Epoch 12/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 35.9607 - root_mean_squared_error: 5.9903 - val_loss: 831.1865 - val_root_mean_squared_error: 28.8303 - learning_rate: 0.0500
# Epoch 13/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 159.3112 - root_mean_squared_error: 12.6172 - val_loss: 9444.4873 - val_root_mean_squared_error: 97.1828 - learning_rate: 0.0500
# Epoch 14/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 143.6416 - root_mean_squared_error: 11.9844 - val_loss: 9066.6299 - val_root_mean_squared_error: 95.2188 - learning_rate: 0.0500
# Epoch 15/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 56.9339 - root_mean_squared_error: 7.5227 - val_loss: 8865.9297 - val_root_mean_squared_error: 94.1591 - learning_rate: 0.0500
# Epoch 16/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 55.9072 - root_mean_squared_error: 7.3590 - val_loss: 9228.9424 - val_root_mean_squared_error: 96.0674 - learning_rate: 0.0500
# Epoch 17/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 87.5450 - root_mean_squared_error: 9.3565 - val_loss: 10883.2773 - val_root_mean_squared_error: 104.3229 - learning_rate: 0.0500
# Epoch 18/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 308.8565 - root_mean_squared_error: 17.5723 - val_loss: 11342.4658 - val_root_mean_squared_error: 106.5010 - learning_rate: 0.0500
# Epoch 19/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 129.9961 - root_mean_squared_error: 11.4013 - val_loss: 11351.2656 - val_root_mean_squared_error: 106.5423 - learning_rate: 0.0500
# Epoch 20/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 57.7082 - root_mean_squared_error: 7.5961 - val_loss: 11328.8086 - val_root_mean_squared_error: 106.4369 - learning_rate: 0.0500
# Epoch 21/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 72.4925 - root_mean_squared_error: 8.5141 - val_loss: 11001.4424 - val_root_mean_squared_error: 104.8878 - learning_rate: 0.0500
# Epoch 22/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 119.3913 - root_mean_squared_error: 10.6809 - val_loss: 10131.7061 - val_root_mean_squared_error: 100.6564 - learning_rate: 0.0500
# Epoch 23/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 66.3889 - root_mean_squared_error: 8.1477 - val_loss: 9202.0176 - val_root_mean_squared_error: 95.9271 - learning_rate: 0.0500
# Epoch 24/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 224.0437 - root_mean_squared_error: 14.9679 - val_loss: 9490.0459 - val_root_mean_squared_error: 97.4169 - learning_rate: 0.0500
# Epoch 25/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 152.5174 - root_mean_squared_error: 12.3411 - val_loss: 10804.7832 - val_root_mean_squared_error: 103.9461 - learning_rate: 0.0500
# Epoch 26/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 68.1127 - root_mean_squared_error: 8.0886 - val_loss: 11672.2266 - val_root_mean_squared_error: 108.0381 - learning_rate: 0.0500
# Epoch 27/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 100.7158 - root_mean_squared_error: 10.0330 - val_loss: 11592.3672 - val_root_mean_squared_error: 107.6679 - learning_rate: 0.0500
# Epoch 28/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 81.4731 - root_mean_squared_error: 8.8836 - val_loss: 10965.4062 - val_root_mean_squared_error: 104.7158 - learning_rate: 0.0500
# Epoch 29/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 134.0209 - root_mean_squared_error: 11.4549 - val_loss: 4977.9731 - val_root_mean_squared_error: 70.5548 - learning_rate: 0.0500
# Epoch 30/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 920.1572 - root_mean_squared_error: 30.3335 - val_loss: 498870.5000 - val_root_mean_squared_error: 706.3077 - learning_rate: 0.0500
# Epoch 31/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 369.3643 - root_mean_squared_error: 19.2169 - val_loss: 1407810.1250 - val_root_mean_squared_error: 1186.5117 - learning_rate: 0.0500
# Epoch 32/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 140.2123 - root_mean_squared_error: 11.8395 - val_loss: 1841526.3750 - val_root_mean_squared_error: 1357.0286 - learning_rate: 0.0500
# Epoch 33/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 165.0548 - root_mean_squared_error: 12.8443 - val_loss: 1111600.6250 - val_root_mean_squared_error: 1054.3247 - learning_rate: 0.0500
# Epoch 34/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 77.7743 - root_mean_squared_error: 8.8172 - val_loss: 451042.4062 - val_root_mean_squared_error: 671.5969 - learning_rate: 0.0500
# Epoch 35/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 131.2231 - root_mean_squared_error: 11.4533 - val_loss: 172275.4844 - val_root_mean_squared_error: 415.0608 - learning_rate: 0.0500
# Epoch 36/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 276.0453 - root_mean_squared_error: 16.6146 - val_loss: 116733.1016 - val_root_mean_squared_error: 341.6623 - learning_rate: 0.0500
# Epoch 37/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 284.6465 - root_mean_squared_error: 16.8659 - val_loss: 159449.4219 - val_root_mean_squared_error: 399.3112 - learning_rate: 0.0500
# Epoch 38/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 127.6907 - root_mean_squared_error: 11.3000 - val_loss: 242653.3125 - val_root_mean_squared_error: 492.5985 - learning_rate: 0.0500
# Epoch 39/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 70.5434 - root_mean_squared_error: 8.3973 - val_loss: 408845.2812 - val_root_mean_squared_error: 639.4101 - learning_rate: 0.0500
# Epoch 40/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 92.1992 - root_mean_squared_error: 9.5876 - val_loss: 393960.4062 - val_root_mean_squared_error: 627.6627 - learning_rate: 0.0500
# Epoch 41/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 158.1392 - root_mean_squared_error: 12.5747 - val_loss: 172320.2031 - val_root_mean_squared_error: 415.1147 - learning_rate: 0.0500
# Epoch 42/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 81.0753 - root_mean_squared_error: 9.0030 - val_loss: 54189.8438 - val_root_mean_squared_error: 232.7871 - learning_rate: 0.0500
# Epoch 43/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 100.8166 - root_mean_squared_error: 9.7612 - val_loss: 27184.2598 - val_root_mean_squared_error: 164.8765 - learning_rate: 0.0500
# Epoch 44/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 96.1997 - root_mean_squared_error: 9.8051 - val_loss: 36293.5586 - val_root_mean_squared_error: 190.5087 - learning_rate: 0.0500
# Epoch 45/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 88.2508 - root_mean_squared_error: 9.3934 - val_loss: 53984.9570 - val_root_mean_squared_error: 232.3466 - learning_rate: 0.0500
# Epoch 46/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 92.1697 - root_mean_squared_error: 9.6005 - val_loss: 62715.9023 - val_root_mean_squared_error: 250.4314 - learning_rate: 0.0500
# Epoch 47/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 106.4126 - root_mean_squared_error: 10.2788 - val_loss: 41932.9805 - val_root_mean_squared_error: 204.7754 - learning_rate: 0.0500
# Epoch 48/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 85.0203 - root_mean_squared_error: 9.1976 - val_loss: 15396.4346 - val_root_mean_squared_error: 124.0824 - learning_rate: 0.0500
# Epoch 49/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 83.2260 - root_mean_squared_error: 9.1220 - val_loss: 4503.3003 - val_root_mean_squared_error: 67.1066 - learning_rate: 0.0500
# Epoch 50/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 176.3325 - root_mean_squared_error: 13.2779 - val_loss: 2040.3457 - val_root_mean_squared_error: 45.1702 - learning_rate: 0.0500
# Epoch 51/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 192.7089 - root_mean_squared_error: 13.7869 - val_loss: 3539.1365 - val_root_mean_squared_error: 59.4906 - learning_rate: 0.0500
# Epoch 52/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 149.7866 - root_mean_squared_error: 12.2370 - val_loss: 11773.3047 - val_root_mean_squared_error: 108.5049 - learning_rate: 0.0500
# Epoch 53/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 94.9422 - root_mean_squared_error: 9.7069 - val_loss: 22175.3848 - val_root_mean_squared_error: 148.9140 - learning_rate: 0.0500
# Epoch 54/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 51.3821 - root_mean_squared_error: 7.1680 - val_loss: 25911.5020 - val_root_mean_squared_error: 160.9705 - learning_rate: 0.0500
# Epoch 55/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 80.8855 - root_mean_squared_error: 8.8142 - val_loss: 31576.1660 - val_root_mean_squared_error: 177.6968 - learning_rate: 0.0500
# Epoch 56/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 75.8836 - root_mean_squared_error: 8.6986 - val_loss: 33826.9844 - val_root_mean_squared_error: 183.9211 - learning_rate: 0.0500
# Epoch 57/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 81.5007 - root_mean_squared_error: 9.0137 - val_loss: 19663.1074 - val_root_mean_squared_error: 140.2252 - learning_rate: 0.0500
# Epoch 58/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 57.9228 - root_mean_squared_error: 7.5851 - val_loss: 7570.3066 - val_root_mean_squared_error: 87.0075 - learning_rate: 0.0500
# Epoch 59/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 84.5134 - root_mean_squared_error: 9.1921 - val_loss: 2271.2581 - val_root_mean_squared_error: 47.6577 - learning_rate: 0.0500
# Epoch 60/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 132.4160 - root_mean_squared_error: 11.5055 - val_loss: 860.1332 - val_root_mean_squared_error: 29.3280 - learning_rate: 0.0500
# Epoch 61/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 168.2044 - root_mean_squared_error: 12.9308 - val_loss: 941.1069 - val_root_mean_squared_error: 30.6775 - learning_rate: 0.0500
# Epoch 62/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 156.4209 - root_mean_squared_error: 12.5033 - val_loss: 2438.4062 - val_root_mean_squared_error: 49.3802 - learning_rate: 0.0500
# Epoch 63/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 93.3424 - root_mean_squared_error: 9.5674 - val_loss: 6039.3638 - val_root_mean_squared_error: 77.7133 - learning_rate: 0.0500
# Epoch 64/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 93.3865 - root_mean_squared_error: 9.6612 - val_loss: 13861.0205 - val_root_mean_squared_error: 117.7328 - learning_rate: 0.0500
# Epoch 65/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 66.0927 - root_mean_squared_error: 8.1222 - val_loss: 19830.9727 - val_root_mean_squared_error: 140.8225 - learning_rate: 0.0500
# Epoch 66/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 146.4864 - root_mean_squared_error: 12.1014 - val_loss: 15595.2695 - val_root_mean_squared_error: 124.8810 - learning_rate: 0.0500
# Epoch 67/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 86.1972 - root_mean_squared_error: 9.2682 - val_loss: 8689.1797 - val_root_mean_squared_error: 93.2158 - learning_rate: 0.0500
# Epoch 68/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 109.8979 - root_mean_squared_error: 10.4686 - val_loss: 3736.8845 - val_root_mean_squared_error: 61.1301 - learning_rate: 0.0500
# Epoch 69/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 56.2434 - root_mean_squared_error: 7.4995 - val_loss: 2662.7664 - val_root_mean_squared_error: 51.6020 - learning_rate: 0.0500
# Epoch 70/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 94.9203 - root_mean_squared_error: 9.7412 - val_loss: 2057.5112 - val_root_mean_squared_error: 45.3598 - learning_rate: 0.0500
# Epoch 71/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 91.0588 - root_mean_squared_error: 9.3984 - val_loss: 2692.7751 - val_root_mean_squared_error: 51.8920 - learning_rate: 0.0500
# Epoch 72/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 53.6961 - root_mean_squared_error: 7.3263 - val_loss: 4893.0151 - val_root_mean_squared_error: 69.9501 - learning_rate: 0.0500
# Epoch 73/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 47.4980 - root_mean_squared_error: 6.8756 - val_loss: 5446.0649 - val_root_mean_squared_error: 73.7975 - learning_rate: 0.0500
# Epoch 74/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 76.6150 - root_mean_squared_error: 8.7522 - val_loss: 3999.9297 - val_root_mean_squared_error: 63.2450 - learning_rate: 0.0500
# Epoch 75/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 60.8448 - root_mean_squared_error: 7.8003 - val_loss: 2645.0457 - val_root_mean_squared_error: 51.4300 - learning_rate: 0.0500
# Epoch 76/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 39.3340 - root_mean_squared_error: 6.2715 - val_loss: 1430.0370 - val_root_mean_squared_error: 37.8158 - learning_rate: 0.0500
# Epoch 77/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 79.7658 - root_mean_squared_error: 8.7676 - val_loss: 1208.1398 - val_root_mean_squared_error: 34.7583 - learning_rate: 0.0500
# Epoch 78/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 82.9497 - root_mean_squared_error: 9.0784 - val_loss: 2349.4995 - val_root_mean_squared_error: 48.4716 - learning_rate: 0.0500
# Epoch 79/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 90.4729 - root_mean_squared_error: 9.4586 - val_loss: 4820.5137 - val_root_mean_squared_error: 69.4299 - learning_rate: 0.0500
# Epoch 80/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 120.6673 - root_mean_squared_error: 10.9740 - val_loss: 9946.8281 - val_root_mean_squared_error: 99.7338 - learning_rate: 0.0500
# Epoch 81/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 199.3407 - root_mean_squared_error: 14.1182 - val_loss: 9460.5078 - val_root_mean_squared_error: 97.2651 - learning_rate: 0.0500
# Epoch 82/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 350.8296 - root_mean_squared_error: 18.7287 - val_loss: 3934.7129 - val_root_mean_squared_error: 62.7273 - learning_rate: 0.0500
# Epoch 83/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 145.6724 - root_mean_squared_error: 12.0613 - val_loss: 853.5444 - val_root_mean_squared_error: 29.2155 - learning_rate: 0.0500
# Epoch 84/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 73.9358 - root_mean_squared_error: 8.5791 - val_loss: 757.6805 - val_root_mean_squared_error: 27.5260 - learning_rate: 0.0500
# Epoch 85/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 113.5099 - root_mean_squared_error: 10.6522 - val_loss: 2112.7925 - val_root_mean_squared_error: 45.9651 - learning_rate: 0.0500
# Epoch 86/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 173.6690 - root_mean_squared_error: 13.1755 - val_loss: 3168.1096 - val_root_mean_squared_error: 56.2860 - learning_rate: 0.0500
# Epoch 87/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 215.3064 - root_mean_squared_error: 14.6732 - val_loss: 3446.0168 - val_root_mean_squared_error: 58.7028 - learning_rate: 0.0500
# Epoch 88/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 223.7633 - root_mean_squared_error: 14.9454 - val_loss: 2604.0286 - val_root_mean_squared_error: 51.0297 - learning_rate: 0.0500
# Epoch 89/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 210.9851 - root_mean_squared_error: 14.5199 - val_loss: 1304.2836 - val_root_mean_squared_error: 36.1149 - learning_rate: 0.0500
# Epoch 90/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 131.1834 - root_mean_squared_error: 11.4526 - val_loss: 523.8278 - val_root_mean_squared_error: 22.8873 - learning_rate: 0.0500
# Epoch 91/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 88.1122 - root_mean_squared_error: 9.3727 - val_loss: 472.3609 - val_root_mean_squared_error: 21.7339 - learning_rate: 0.0500
# Epoch 92/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 68.6630 - root_mean_squared_error: 8.2708 - val_loss: 445.1516 - val_root_mean_squared_error: 21.0986 - learning_rate: 0.0500
# Epoch 93/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 76.3184 - root_mean_squared_error: 8.6493 - val_loss: 510.0830 - val_root_mean_squared_error: 22.5850 - learning_rate: 0.0500
# Epoch 94/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 67.2008 - root_mean_squared_error: 8.1525 - val_loss: 902.5114 - val_root_mean_squared_error: 30.0418 - learning_rate: 0.0500
# Epoch 95/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 95.4193 - root_mean_squared_error: 9.7304 - val_loss: 1502.1586 - val_root_mean_squared_error: 38.7577 - learning_rate: 0.0500
# Epoch 96/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 84.6504 - root_mean_squared_error: 9.2000 - val_loss: 1577.4106 - val_root_mean_squared_error: 39.7166 - learning_rate: 0.0500
# Epoch 97/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 107.7107 - root_mean_squared_error: 10.3766 - val_loss: 1718.9613 - val_root_mean_squared_error: 41.4604 - learning_rate: 0.0500
# Epoch 98/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 64.9578 - root_mean_squared_error: 8.0591 - val_loss: 1998.1859 - val_root_mean_squared_error: 44.7011 - learning_rate: 0.0500
# Epoch 99/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 44.0893 - root_mean_squared_error: 6.6341 - val_loss: 2113.4773 - val_root_mean_squared_error: 45.9726 - learning_rate: 0.0500
# Epoch 100/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 37.9967 - root_mean_squared_error: 6.1635 - val_loss: 1977.5028 - val_root_mean_squared_error: 44.4691 - learning_rate: 0.0500
# Epoch 101/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 50.6354 - root_mean_squared_error: 7.1158 - val_loss: 1862.3564 - val_root_mean_squared_error: 43.1550 - learning_rate: 0.0500
# Epoch 102/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 74.2199 - root_mean_squared_error: 8.6150 - val_loss: 1813.0397 - val_root_mean_squared_error: 42.5798 - learning_rate: 5.0000e-04
# Epoch 103/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 72.6889 - root_mean_squared_error: 8.4874 - val_loss: 1749.9730 - val_root_mean_squared_error: 41.8327 - learning_rate: 5.0000e-04
# Epoch 104/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 126.1390 - root_mean_squared_error: 11.2181 - val_loss: 1696.2178 - val_root_mean_squared_error: 41.1852 - learning_rate: 5.0000e-04
# Epoch 105/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 107.9017 - root_mean_squared_error: 10.2495 - val_loss: 1667.5277 - val_root_mean_squared_error: 40.8354 - learning_rate: 5.0000e-04
# Epoch 106/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 96.5835 - root_mean_squared_error: 9.8130 - val_loss: 1629.7305 - val_root_mean_squared_error: 40.3699 - learning_rate: 5.0000e-04
# Epoch 107/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 57.6296 - root_mean_squared_error: 7.5840 - val_loss: 1571.4067 - val_root_mean_squared_error: 39.6410 - learning_rate: 5.0000e-04
# Epoch 108/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 60.4243 - root_mean_squared_error: 7.7644 - val_loss: 1520.5641 - val_root_mean_squared_error: 38.9944 - learning_rate: 5.0000e-04
# Epoch 109/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 59.9273 - root_mean_squared_error: 7.7394 - val_loss: 1483.7681 - val_root_mean_squared_error: 38.5197 - learning_rate: 5.0000e-04
# Epoch 110/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 49.1684 - root_mean_squared_error: 7.0109 - val_loss: 1446.3993 - val_root_mean_squared_error: 38.0316 - learning_rate: 5.0000e-04
# Epoch 111/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 87.2635 - root_mean_squared_error: 9.3414 - val_loss: 1407.4733 - val_root_mean_squared_error: 37.5163 - learning_rate: 5.0000e-04
# Epoch 112/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 42.5915 - root_mean_squared_error: 6.5257 - val_loss: 1362.6058 - val_root_mean_squared_error: 36.9135 - learning_rate: 5.0000e-04
# Epoch 113/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 109.3078 - root_mean_squared_error: 10.4082 - val_loss: 1318.7109 - val_root_mean_squared_error: 36.3141 - learning_rate: 5.0000e-04
# Epoch 114/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 61.9199 - root_mean_squared_error: 7.8677 - val_loss: 1287.5294 - val_root_mean_squared_error: 35.8822 - learning_rate: 5.0000e-04
# Epoch 115/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 47.9663 - root_mean_squared_error: 6.9254 - val_loss: 1257.1914 - val_root_mean_squared_error: 35.4569 - learning_rate: 5.0000e-04
# Epoch 116/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 80.0713 - root_mean_squared_error: 8.9461 - val_loss: 1229.5830 - val_root_mean_squared_error: 35.0654 - learning_rate: 5.0000e-04
# Epoch 117/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 58.4748 - root_mean_squared_error: 7.6440 - val_loss: 1195.9498 - val_root_mean_squared_error: 34.5825 - learning_rate: 5.0000e-04
# Epoch 118/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 68.0464 - root_mean_squared_error: 8.2489 - val_loss: 1170.7347 - val_root_mean_squared_error: 34.2160 - learning_rate: 5.0000e-04
# Epoch 119/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 71.2439 - root_mean_squared_error: 8.4388 - val_loss: 1142.6832 - val_root_mean_squared_error: 33.8036 - learning_rate: 5.0000e-04
# Epoch 120/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 103.2975 - root_mean_squared_error: 10.1598 - val_loss: 1112.8414 - val_root_mean_squared_error: 33.3593 - learning_rate: 5.0000e-04
# Epoch 121/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 44.2694 - root_mean_squared_error: 6.6533 - val_loss: 1087.5586 - val_root_mean_squared_error: 32.9782 - learning_rate: 5.0000e-04
# Epoch 122/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 44.8420 - root_mean_squared_error: 6.6825 - val_loss: 1061.7030 - val_root_mean_squared_error: 32.5838 - learning_rate: 5.0000e-04
# Epoch 123/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 159.4259 - root_mean_squared_error: 12.6171 - val_loss: 1023.9210 - val_root_mean_squared_error: 31.9988 - learning_rate: 5.0000e-04
# Epoch 124/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 44.9344 - root_mean_squared_error: 6.7020 - val_loss: 996.5139 - val_root_mean_squared_error: 31.5676 - learning_rate: 5.0000e-04
# Epoch 125/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 107.9911 - root_mean_squared_error: 10.3912 - val_loss: 972.0604 - val_root_mean_squared_error: 31.1779 - learning_rate: 5.0000e-04
# Epoch 126/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 89.5576 - root_mean_squared_error: 9.4634 - val_loss: 951.2990 - val_root_mean_squared_error: 30.8431 - learning_rate: 5.0000e-04
# Epoch 127/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 133.4813 - root_mean_squared_error: 11.3938 - val_loss: 924.6046 - val_root_mean_squared_error: 30.4073 - learning_rate: 5.0000e-04
# Epoch 128/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 75.6252 - root_mean_squared_error: 8.6468 - val_loss: 920.6566 - val_root_mean_squared_error: 30.3423 - learning_rate: 5.0000e-04
# Epoch 129/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 70.9022 - root_mean_squared_error: 8.3883 - val_loss: 895.8967 - val_root_mean_squared_error: 29.9315 - learning_rate: 5.0000e-04
# Epoch 130/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 63.0492 - root_mean_squared_error: 7.9403 - val_loss: 877.0925 - val_root_mean_squared_error: 29.6157 - learning_rate: 5.0000e-04
# Epoch 131/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 70.1274 - root_mean_squared_error: 8.3641 - val_loss: 854.5088 - val_root_mean_squared_error: 29.2320 - learning_rate: 5.0000e-04
# Epoch 132/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 59.1006 - root_mean_squared_error: 7.6877 - val_loss: 837.2591 - val_root_mean_squared_error: 28.9354 - learning_rate: 5.0000e-04
# Epoch 133/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 138.6496 - root_mean_squared_error: 11.7749 - val_loss: 819.9844 - val_root_mean_squared_error: 28.6354 - learning_rate: 5.0000e-04
# Epoch 134/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 100.5836 - root_mean_squared_error: 10.0174 - val_loss: 802.6074 - val_root_mean_squared_error: 28.3303 - learning_rate: 5.0000e-04
# Epoch 135/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 62.2607 - root_mean_squared_error: 7.8905 - val_loss: 792.5349 - val_root_mean_squared_error: 28.1520 - learning_rate: 5.0000e-04
# Epoch 136/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 58.5236 - root_mean_squared_error: 7.6497 - val_loss: 774.2424 - val_root_mean_squared_error: 27.8252 - learning_rate: 5.0000e-04
# Epoch 137/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 99.9740 - root_mean_squared_error: 9.9706 - val_loss: 763.9265 - val_root_mean_squared_error: 27.6392 - learning_rate: 5.0000e-04
# Epoch 138/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 95.5382 - root_mean_squared_error: 9.6425 - val_loss: 750.0113 - val_root_mean_squared_error: 27.3863 - learning_rate: 5.0000e-04
# Epoch 139/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 36.4443 - root_mean_squared_error: 6.0363 - val_loss: 732.7733 - val_root_mean_squared_error: 27.0698 - learning_rate: 5.0000e-04
# Epoch 140/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 75.5504 - root_mean_squared_error: 8.6906 - val_loss: 708.1754 - val_root_mean_squared_error: 26.6116 - learning_rate: 5.0000e-04
# Epoch 141/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 54.9518 - root_mean_squared_error: 7.4048 - val_loss: 687.6934 - val_root_mean_squared_error: 26.2239 - learning_rate: 5.0000e-04
# Epoch 142/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 74.7663 - root_mean_squared_error: 8.6465 - val_loss: 675.3284 - val_root_mean_squared_error: 25.9871 - learning_rate: 5.0000e-04
# Epoch 143/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 71.2843 - root_mean_squared_error: 8.4240 - val_loss: 659.4283 - val_root_mean_squared_error: 25.6793 - learning_rate: 5.0000e-04
# Epoch 144/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 66.2513 - root_mean_squared_error: 8.1378 - val_loss: 643.2531 - val_root_mean_squared_error: 25.3624 - learning_rate: 5.0000e-04
# Epoch 145/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 36.9281 - root_mean_squared_error: 6.0761 - val_loss: 632.9620 - val_root_mean_squared_error: 25.1587 - learning_rate: 5.0000e-04
# Epoch 146/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 36.8823 - root_mean_squared_error: 6.0717 - val_loss: 621.3467 - val_root_mean_squared_error: 24.9268 - learning_rate: 5.0000e-04
# Epoch 147/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 62.1041 - root_mean_squared_error: 7.8795 - val_loss: 610.5664 - val_root_mean_squared_error: 24.7096 - learning_rate: 5.0000e-04
# Epoch 148/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 60.1410 - root_mean_squared_error: 7.7538 - val_loss: 594.0106 - val_root_mean_squared_error: 24.3723 - learning_rate: 5.0000e-04
# Epoch 149/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 59.4867 - root_mean_squared_error: 7.7114 - val_loss: 584.7388 - val_root_mean_squared_error: 24.1814 - learning_rate: 5.0000e-04
# Epoch 150/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 72.9264 - root_mean_squared_error: 8.5249 - val_loss: 567.4475 - val_root_mean_squared_error: 23.8212 - learning_rate: 5.0000e-04
# Epoch 151/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 99.6439 - root_mean_squared_error: 9.8992 - val_loss: 565.7222 - val_root_mean_squared_error: 23.7849 - learning_rate: 5.0000e-04
# Epoch 152/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 58.9560 - root_mean_squared_error: 7.4577 - val_loss: 556.9283 - val_root_mean_squared_error: 23.5993 - learning_rate: 5.0000e-04
# Epoch 153/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 94.6971 - root_mean_squared_error: 9.7297 - val_loss: 539.2769 - val_root_mean_squared_error: 23.2223 - learning_rate: 5.0000e-04
# Epoch 154/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 49.9465 - root_mean_squared_error: 7.0653 - val_loss: 529.7188 - val_root_mean_squared_error: 23.0156 - learning_rate: 5.0000e-04
# Epoch 155/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 105.8595 - root_mean_squared_error: 10.0714 - val_loss: 525.0346 - val_root_mean_squared_error: 22.9136 - learning_rate: 5.0000e-04
# Epoch 156/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 39.8967 - root_mean_squared_error: 6.3149 - val_loss: 513.0013 - val_root_mean_squared_error: 22.6495 - learning_rate: 5.0000e-04
# Epoch 157/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 52.6867 - root_mean_squared_error: 7.2408 - val_loss: 499.4564 - val_root_mean_squared_error: 22.3485 - learning_rate: 5.0000e-04
# Epoch 158/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 57.4963 - root_mean_squared_error: 7.5750 - val_loss: 489.3000 - val_root_mean_squared_error: 22.1201 - learning_rate: 5.0000e-04
# Epoch 159/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 71.3194 - root_mean_squared_error: 8.4448 - val_loss: 483.9771 - val_root_mean_squared_error: 21.9995 - learning_rate: 5.0000e-04
# Epoch 160/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 67.2984 - root_mean_squared_error: 8.1947 - val_loss: 474.2926 - val_root_mean_squared_error: 21.7783 - learning_rate: 5.0000e-04
# Epoch 161/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 61.2970 - root_mean_squared_error: 7.8199 - val_loss: 468.6836 - val_root_mean_squared_error: 21.6491 - learning_rate: 5.0000e-04
# Epoch 162/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 47.8030 - root_mean_squared_error: 6.9136 - val_loss: 466.8093 - val_root_mean_squared_error: 21.6058 - learning_rate: 5.0000e-04
# Epoch 163/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 105.1605 - root_mean_squared_error: 10.2547 - val_loss: 463.8438 - val_root_mean_squared_error: 21.5370 - learning_rate: 5.0000e-04
# Epoch 164/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 48.7405 - root_mean_squared_error: 6.9803 - val_loss: 457.9334 - val_root_mean_squared_error: 21.3994 - learning_rate: 5.0000e-04
# Epoch 165/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 45.8296 - root_mean_squared_error: 6.7692 - val_loss: 455.5396 - val_root_mean_squared_error: 21.3434 - learning_rate: 5.0000e-04
# Epoch 166/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 63.5974 - root_mean_squared_error: 7.9372 - val_loss: 450.8297 - val_root_mean_squared_error: 21.2328 - learning_rate: 5.0000e-04
# Epoch 167/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 50.3930 - root_mean_squared_error: 7.0806 - val_loss: 448.2810 - val_root_mean_squared_error: 21.1726 - learning_rate: 5.0000e-04
# Epoch 168/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 34.0078 - root_mean_squared_error: 5.8284 - val_loss: 447.5630 - val_root_mean_squared_error: 21.1557 - learning_rate: 5.0000e-04
# Epoch 169/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 34.4735 - root_mean_squared_error: 5.8698 - val_loss: 446.4504 - val_root_mean_squared_error: 21.1294 - learning_rate: 5.0000e-04
# Epoch 170/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 323ms/step - loss: 85.5092 - root_mean_squared_error: 9.2469 - val_loss: 445.2986 - val_root_mean_squared_error: 21.1021 - learning_rate: 5.0000e-04
# Epoch 171/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 298ms/step - loss: 54.1197 - root_mean_squared_error: 7.3505 - val_loss: 442.6935 - val_root_mean_squared_error: 21.0403 - learning_rate: 5.0000e-04
# Epoch 172/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 79.6277 - root_mean_squared_error: 8.9179 - val_loss: 441.6169 - val_root_mean_squared_error: 21.0147 - learning_rate: 5.0000e-04
# Epoch 173/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 86.7674 - root_mean_squared_error: 9.3149 - val_loss: 439.0780 - val_root_mean_squared_error: 20.9542 - learning_rate: 5.0000e-04
# Epoch 174/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 49.8210 - root_mean_squared_error: 7.0522 - val_loss: 438.4276 - val_root_mean_squared_error: 20.9387 - learning_rate: 5.0000e-04
# Epoch 175/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 61.2707 - root_mean_squared_error: 7.8225 - val_loss: 437.2043 - val_root_mean_squared_error: 20.9094 - learning_rate: 5.0000e-04
# Epoch 176/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 73.6733 - root_mean_squared_error: 8.5601 - val_loss: 436.8282 - val_root_mean_squared_error: 20.9004 - learning_rate: 5.0000e-04
# Epoch 177/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 52.0682 - root_mean_squared_error: 7.2152 - val_loss: 436.3960 - val_root_mean_squared_error: 20.8901 - learning_rate: 5.0000e-04
# Epoch 178/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 59.5615 - root_mean_squared_error: 7.7155 - val_loss: 435.9041 - val_root_mean_squared_error: 20.8783 - learning_rate: 5.0000e-04
# Epoch 179/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 61.4534 - root_mean_squared_error: 7.8392 - val_loss: 436.1147 - val_root_mean_squared_error: 20.8834 - learning_rate: 5.0000e-04
# Epoch 180/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 82.5514 - root_mean_squared_error: 9.0789 - val_loss: 436.0291 - val_root_mean_squared_error: 20.8813 - learning_rate: 5.0000e-04
# Epoch 181/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 78.1459 - root_mean_squared_error: 8.8385 - val_loss: 436.1273 - val_root_mean_squared_error: 20.8837 - learning_rate: 5.0000e-04
# Epoch 182/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 65.4951 - root_mean_squared_error: 8.0904 - val_loss: 436.5520 - val_root_mean_squared_error: 20.8938 - learning_rate: 5.0000e-05
# Epoch 183/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 115.8964 - root_mean_squared_error: 10.7654 - val_loss: 436.7646 - val_root_mean_squared_error: 20.8989 - learning_rate: 5.0000e-05
# Epoch 184/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 94.8799 - root_mean_squared_error: 9.7403 - val_loss: 437.5378 - val_root_mean_squared_error: 20.9174 - learning_rate: 5.0000e-05
# Epoch 185/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 62.6684 - root_mean_squared_error: 7.9157 - val_loss: 439.8786 - val_root_mean_squared_error: 20.9733 - learning_rate: 5.0000e-05
# Epoch 186/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 70.6419 - root_mean_squared_error: 8.4021 - val_loss: 443.2465 - val_root_mean_squared_error: 21.0534 - learning_rate: 5.0000e-05
# Epoch 187/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 46.1220 - root_mean_squared_error: 6.7909 - val_loss: 447.2944 - val_root_mean_squared_error: 21.1493 - learning_rate: 5.0000e-05
# Epoch 188/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 74.1780 - root_mean_squared_error: 8.6120 - val_loss: 449.6205 - val_root_mean_squared_error: 21.2043 - learning_rate: 5.0000e-05
# Epoch 189/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 73.6065 - root_mean_squared_error: 8.5782 - val_loss: 452.0023 - val_root_mean_squared_error: 21.2603 - learning_rate: 5.0000e-05
# Epoch 190/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 112.6557 - root_mean_squared_error: 10.6138 - val_loss: 457.3676 - val_root_mean_squared_error: 21.3862 - learning_rate: 5.0000e-05
# Epoch 191/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 67.5230 - root_mean_squared_error: 8.2109 - val_loss: 458.7498 - val_root_mean_squared_error: 21.4184 - learning_rate: 5.0000e-05
# Epoch 192/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 35.9536 - root_mean_squared_error: 5.9961 - val_loss: 461.2718 - val_root_mean_squared_error: 21.4772 - learning_rate: 1.0000e-05
# Epoch 193/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 39.6329 - root_mean_squared_error: 6.2913 - val_loss: 467.4430 - val_root_mean_squared_error: 21.6204 - learning_rate: 1.0000e-05
# Epoch 194/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 56.7304 - root_mean_squared_error: 7.5216 - val_loss: 473.2615 - val_root_mean_squared_error: 21.7546 - learning_rate: 1.0000e-05
# Epoch 195/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 46.8877 - root_mean_squared_error: 6.8391 - val_loss: 475.9642 - val_root_mean_squared_error: 21.8166 - learning_rate: 1.0000e-05
# Epoch 196/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 65.4312 - root_mean_squared_error: 8.0353 - val_loss: 479.2507 - val_root_mean_squared_error: 21.8918 - learning_rate: 1.0000e-05
# Epoch 197/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 54.8432 - root_mean_squared_error: 7.4000 - val_loss: 478.8297 - val_root_mean_squared_error: 21.8822 - learning_rate: 1.0000e-05
# Epoch 198/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 115.9965 - root_mean_squared_error: 10.7506 - val_loss: 488.8467 - val_root_mean_squared_error: 22.1099 - learning_rate: 1.0000e-05
# Epoch 199/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 56.9103 - root_mean_squared_error: 7.5424 - val_loss: 497.8034 - val_root_mean_squared_error: 22.3115 - learning_rate: 1.0000e-05
# Epoch 200/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 109.5148 - root_mean_squared_error: 10.3940 - val_loss: 487.9074 - val_root_mean_squared_error: 22.0886 - learning_rate: 1.0000e-05

# %%
# Extrae los últimos 30 días de datos como secuencia de entrada
input_sequence = df['y'][-30:].to_numpy().reshape(1, 30, 1)

# Lista para almacenar las predicciones
predictions = []

# Genera 20 predicciones avanzando un día a la vez
for _ in range(20):
    # Realiza la predicción para el siguiente día
    next_pred = my_LSTM_model.predict(input_sequence)[0, -1]  # Obtiene el valor predicho

    # Agrega la predicción a la lista de predicciones
    predictions.append(next_pred)

    # Ajusta el valor predicho para tener tres dimensiones
    next_pred = np.array([[next_pred]])  # Convierte a array con dimensión (1, 1)

    # Actualiza la secuencia de entrada: elimina el primer valor y agrega el nuevo predicho
    input_sequence = np.append(input_sequence[:, 1:, :], next_pred[:, np.newaxis, :], axis=1)

# Convierte las predicciones en un array o DataFrame si lo deseas para su análisis
predictions_array = np.array(predictions)
print("Predicciones para los últimos 20 días:", predictions_array)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicciones para los últimos 20 días: [149.58379 153.40854 157.108   160.86336 163.18268 164.35172 165.57144
#  165.94936 165.2872  165.89421 168.75099 171.1526  173.95859 174.7791
#  173.00114 172.22322 172.6638  172.30133 171.26668 169.14835]

# %%
# Extrae los últimos 30 valores de prueba para comparar con las predicciones
test_last_30_days = Test_Y[-1].flatten()[-30:]  # Últimos 30 días reales

# Calcula el RMSE entre las últimas 20 predicciones y los valores reales correspondientes
rmse = mean_squared_error(test_last_30_days[-20:], predictions_array, squared=False)

# Graficamos los últimos 30 días de prueba y superponemos las predicciones para los últimos 20 días
plt.figure(figsize=(10, 5))
plt.plot(range(30), test_last_30_days, label="Valores reales (últimos 30 días)", color="blue")
plt.plot(range(10, 30), predictions_array, label="Predicciones (últimos 20 días)", color="red", linestyle="--")
plt.xlabel("Días")
plt.ylabel("Valor")
plt.title("Comparación entre valores reales y predicciones para los últimos 30 días")
plt.legend()
plt.show()

# %%
rmse
# Out:
# 30.15311471236744

# %% [markdown]
# # Modelos Escalados

# %% [markdown]
# ## Modelo Ingenuo

# %%
# Crear el escalador y ajustar sobre los datos de entrenamiento
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(trainp[['y']])
test_scaled = scaler.transform(testp[['y']])

# Crear el modelo ingenuo (asume que el valor predicho es el último valor conocido)
def naive_forecast(data):
    return np.roll(data, shift=1)  # Mueve los valores un paso hacia adelante
naive_train_pred = naive_forecast(train_scaled)
naive_test_pred = naive_forecast(test_scaled)

# Invertir la escala para obtener las predicciones en la escala original
naive_train_pred_inversed = scaler.inverse_transform(naive_train_pred.reshape(-1, 1))
naive_test_pred_inversed = scaler.inverse_transform(naive_test_pred.reshape(-1, 1))

# Calcular el RMSE en la escala original
from sklearn.metrics import mean_squared_error

train_rmse = np.sqrt(mean_squared_error(trainp['y'][1:], naive_train_pred_inversed[1:]))
test_rmse = np.sqrt(mean_squared_error(testp['y'][1:], naive_test_pred_inversed[1:]))

print(f'RMSE del modelo ingenuo en el conjunto de entrenamiento: {train_rmse:.3f}')
print(f'RMSE del modelo ingenuo en el conjunto de prueba: {test_rmse:.3f}')
# Out:
# RMSE del modelo ingenuo en el conjunto de entrenamiento: 1.602
# RMSE del modelo ingenuo en el conjunto de prueba: 3.429

# %% [markdown]
# ## Modelo Arima

# %%
# Escalar los datos de entrenamiento y de prueba
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(trainp[['y']])
test_scaled = scaler.transform(testp[['y']])

# Ajustar el modelo ARIMA en los datos escalados de entrenamiento
# Nota: (p, d, q) son los parámetros del modelo ARIMA. Ajustarlos según tu serie de tiempo.
p, d, q = 1, 1, 1  # Cambiar estos valores según corresponda
arima_model = ARIMA(train_scaled, order=(p, d, q))
arima_model_fit = arima_model.fit()

# Generar predicciones usando el modelo ARIMA en los datos de prueba
pred_scaled = arima_model_fit.forecast(steps=len(test_scaled))

# Invertir la escala de las predicciones
pred_inversed = scaler.inverse_transform(pred_scaled.reshape(-1, 1))
test_inversed = scaler.inverse_transform(test_scaled)

# Calcular el RMSE en la escala original
rmse = np.sqrt(mean_squared_error(test_inversed, pred_inversed))
print(f'RMSE del modelo ARIMA en el conjunto de prueba: {rmse:.3f}')
# Out:
# RMSE del modelo ARIMA en el conjunto de prueba: 5.168

# %%
# Verificar las columnas actuales en el DataFrame
print("Columnas actuales en data:", data.columns)
# Out:
# Columnas actuales en data: Index(['Adj Close'], dtype='object')

# %%
if 'Adj Close' in data.columns:
    data = data.rename(columns={'Adj Close': 'y'})

# Verificar si la columna 'y' existe después del renombrado
if 'y' not in data.columns:
    print("Error: La columna 'y' no está presente en el DataFrame.")
else:
    # 1. Calcular estadísticas básicas
    mean_value = data['y'].mean()
    min_value = data['y'].min()
    max_value = data['y'].max()
    range_value = max_value - min_value

    # 2. Calcular RMSE relativo
    rmse = 4.8  # tu valor de RMSE

    # Calcular el RMSE relativo como porcentaje del valor promedio y del rango
    rmse_relative_to_mean = (rmse / mean_value) * 100  # porcentaje respecto a la media
    rmse_relative_to_range = (rmse / range_value) * 100  # porcentaje respecto al rango

    # Imprimir los resultados
    print(f"Valor promedio de los datos: {mean_value}")
    print(f"Valor mínimo de los datos: {min_value}")
    print(f"Valor máximo de los datos: {max_value}")
    print(f"Rango de los datos: {range_value}")
    print(f"RMSE relativo al valor promedio: {rmse_relative_to_mean:.2f}%")
    print(f"RMSE relativo al rango: {rmse_relative_to_range:.2f}%")
# Out:
# Valor promedio de los datos: 34.995072821902625
# Valor mínimo de los datos: 4.892763137817383
# Valor máximo de los datos: 148.8800048828125
# Rango de los datos: 143.98724174499512
# RMSE relativo al valor promedio: 13.72%
# RMSE relativo al rango: 3.33%

# %% [markdown]
# ## Modelo Propeth

# %%
# Crear copias de los datos de entrenamiento y prueba para escalar
train_escalado = trainp.copy()
test_escalado = testp.copy()

# Inicializar el escalador con el intervalo [0, 1]
scaler = MinMaxScaler(feature_range=(0, 1))

# Ajustar el escalador en los datos de entrenamiento y transformar
train_escalado[['y']] = scaler.fit_transform(train_escalado[['y']])

# Transformar el conjunto de prueba utilizando el mismo escalador
test_escalado[['y']] = scaler.transform(test_escalado[['y']])

# Mostrar los resultados escalados para verificar
print("Datos de entrenamiento escalados:")
print(train_escalado.head())

print("\nDatos de prueba escalados:")
print(test_escalado.head())
# Out:
# Datos de entrenamiento escalados:
#            ds         y
# 0  2019-11-15  0.001349
# 1  2019-11-18  0.002799
# 2  2019-11-19  0.002030
# 3  2019-11-20  0.002602
# 4  2019-11-21  0.002423
#
# Datos de prueba escalados:
#            ds         y
# 0  2024-10-28  0.977020
# 1  2024-10-29  0.982279
# 2  2024-10-30  0.968520
# 3  2024-10-31  0.921119
# 4  2024-11-01  0.940137

# %%
# 1. Configurar y ajustar el modelo Prophet con los datos de entrenamiento escalados
model = Prophet(
    seasonality_mode='multiplicative',
    yearly_seasonality=False,
    changepoint_prior_scale=10.0,
    seasonality_prior_scale=2
)

# Ajustar el modelo con los datos de entrenamiento escalados
model.fit(train_escalado)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp3cyy1t0l/pqhxqas3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp3cyy1t0l/0vyl00_h.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75813', 'data', 'file=/tmp/tmp3cyy1t0l/pqhxqas3.json', 'init=/tmp/tmp3cyy1t0l/0vyl00_h.json', 'output', 'file=/tmp/tmp3cyy1t0l/prophet_model4ew421e6/prophet_model-20241113055554.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:55:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:55:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
# 2. Hacer predicciones con el conjunto de prueba escalado
# Crear un DataFrame para el futuro en base al conjunto de prueba
future = test_escalado[['ds']]
forecast = model.predict(future)

# %%
# 3. Calcular el RMSE entre los valores reales y las predicciones
# Extraer la columna 'yhat' de las predicciones
pred_fp = forecast['yhat']

# %%
# Hacer predicciones con el conjunto de prueba escalado
# Crear un DataFrame para el futuro en base al conjunto de prueba
future = test_escalado[['ds']]
forecast = model.predict(future)

# Extraer la columna 'yhat' de las predicciones como la variable pred_fp
pred_fp = forecast['yhat']

# Calcular el RMSE entre las predicciones y los valores reales en el conjunto de prueba
rmse = np.sqrt(mean_squared_error(test_escalado['y'], pred_fp))
print(f"\nError - Modelo Facebook Prophet escalado: RMSE {rmse:.3f}")
# Out:
# Error - Modelo Facebook Prophet escalado: RMSE 0.033

# %% [markdown]
# ## Modelo LSTM

# %%
# Crear una copia de los datos originales
df_scaled = df.copy()

# Inicializar el escalador con el intervalo [0,1]
scaler = MinMaxScaler(feature_range=(0, 1))

# Ajustar el escalador a la columna 'y' y transformar los datos
df_scaled['y'] = scaler.fit_transform(df[['y']])

# Verificar los datos escalados
print(df_scaled.head())
# Out:
#           ds         y
# 0 2019-11-13  0.002057
# 1 2019-11-14  0.002268
# 2 2019-11-15  0.001301
# 3 2019-11-18  0.002698
# 4 2019-11-19  0.001957

# %%
# Obtener la fecha límite para dividir el conjunto de entrenamiento y prueba
threshold_date = pd.to_datetime('2022-11-30')  # Ajusta según tu fecha de división

# Preparar datos escalados para entrenamiento y prueba
Train_X, Train_Y, Test_X, Test_Y = preparando_datos(df_scaled, threshold_date, periodo=30)  # Ajusta el período según sea necesario

# %%
# Definir y compilar el modelo
my_LSTM_model = myModel()
my_LSTM_model.compile(optimizer=tf.keras.optimizers.Adam(), loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Configurar el callback para ajustar el learning rate
callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

# Entrenar el modelo con los datos escalados
H = my_LSTM_model.fit(Train_X, Train_Y, epochs=200, validation_data=(Test_X, Test_Y), callbacks=[callback])
# Out:
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0079 - root_mean_squared_error: 0.0889 - val_loss: 0.1200 - val_root_mean_squared_error: 0.3464 - learning_rate: 0.0500
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0372 - root_mean_squared_error: 0.1928 - val_loss: 0.2680 - val_root_mean_squared_error: 0.5177 - learning_rate: 0.0500
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0125 - root_mean_squared_error: 0.1120 - val_loss: 0.2545 - val_root_mean_squared_error: 0.5044 - learning_rate: 0.0500
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0106 - root_mean_squared_error: 0.1031 - val_loss: 0.2039 - val_root_mean_squared_error: 0.4516 - learning_rate: 0.0500
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0112 - root_mean_squared_error: 0.1058 - val_loss: 0.2194 - val_root_mean_squared_error: 0.4684 - learning_rate: 0.0500
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0058 - root_mean_squared_error: 0.0763 - val_loss: 0.2124 - val_root_mean_squared_error: 0.4609 - learning_rate: 0.0500
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0084 - root_mean_squared_error: 0.0915 - val_loss: 0.2395 - val_root_mean_squared_error: 0.4894 - learning_rate: 0.0500
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0081 - root_mean_squared_error: 0.0900 - val_loss: 0.2154 - val_root_mean_squared_error: 0.4641 - learning_rate: 0.0500
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0068 - root_mean_squared_error: 0.0827 - val_loss: 0.1973 - val_root_mean_squared_error: 0.4442 - learning_rate: 0.0500
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0064 - root_mean_squared_error: 0.0803 - val_loss: 0.1985 - val_root_mean_squared_error: 0.4455 - learning_rate: 0.0500
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0042 - root_mean_squared_error: 0.0652 - val_loss: 0.1912 - val_root_mean_squared_error: 0.4373 - learning_rate: 0.0500
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0037 - root_mean_squared_error: 0.0606 - val_loss: 0.1945 - val_root_mean_squared_error: 0.4410 - learning_rate: 0.0500
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0034 - root_mean_squared_error: 0.0580 - val_loss: 0.1817 - val_root_mean_squared_error: 0.4263 - learning_rate: 0.0500
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0040 - root_mean_squared_error: 0.0632 - val_loss: 0.1974 - val_root_mean_squared_error: 0.4443 - learning_rate: 0.0500
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0026 - root_mean_squared_error: 0.0511 - val_loss: 0.1936 - val_root_mean_squared_error: 0.4400 - learning_rate: 0.0500
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0034 - root_mean_squared_error: 0.0585 - val_loss: 0.2105 - val_root_mean_squared_error: 0.4588 - learning_rate: 0.0500
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 0.0032 - root_mean_squared_error: 0.0569 - val_loss: 0.2102 - val_root_mean_squared_error: 0.4584 - learning_rate: 0.0500
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0028 - root_mean_squared_error: 0.0525 - val_loss: 0.1934 - val_root_mean_squared_error: 0.4398 - learning_rate: 0.0500
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0033 - root_mean_squared_error: 0.0575 - val_loss: 0.2349 - val_root_mean_squared_error: 0.4847 - learning_rate: 0.0500
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0032 - root_mean_squared_error: 0.0566 - val_loss: 0.2273 - val_root_mean_squared_error: 0.4767 - learning_rate: 0.0500
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0032 - root_mean_squared_error: 0.0566 - val_loss: 0.1855 - val_root_mean_squared_error: 0.4307 - learning_rate: 0.0500
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0037 - root_mean_squared_error: 0.0608 - val_loss: 0.1914 - val_root_mean_squared_error: 0.4375 - learning_rate: 0.0500
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0033 - root_mean_squared_error: 0.0571 - val_loss: 0.2334 - val_root_mean_squared_error: 0.4831 - learning_rate: 0.0500
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 0.0038 - root_mean_squared_error: 0.0619 - val_loss: 0.2284 - val_root_mean_squared_error: 0.4779 - learning_rate: 0.0500
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0056 - root_mean_squared_error: 0.0748 - val_loss: 0.2025 - val_root_mean_squared_error: 0.4500 - learning_rate: 0.0500
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.0036 - root_mean_squared_error: 0.0596 - val_loss: 0.1807 - val_root_mean_squared_error: 0.4251 - learning_rate: 0.0500
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0042 - root_mean_squared_error: 0.0647 - val_loss: 0.2083 - val_root_mean_squared_error: 0.4564 - learning_rate: 0.0500
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0026 - root_mean_squared_error: 0.0513 - val_loss: 0.2334 - val_root_mean_squared_error: 0.4831 - learning_rate: 0.0500
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0032 - root_mean_squared_error: 0.0565 - val_loss: 0.2021 - val_root_mean_squared_error: 0.4496 - learning_rate: 0.0500
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.0025 - root_mean_squared_error: 0.0503 - val_loss: 0.1586 - val_root_mean_squared_error: 0.3983 - learning_rate: 0.0500
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 0.0045 - root_mean_squared_error: 0.0674 - val_loss: 0.2164 - val_root_mean_squared_error: 0.4652 - learning_rate: 0.0500
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0030 - root_mean_squared_error: 0.0546 - val_loss: 0.2263 - val_root_mean_squared_error: 0.4757 - learning_rate: 0.0500
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 0.0041 - root_mean_squared_error: 0.0643 - val_loss: 0.1965 - val_root_mean_squared_error: 0.4433 - learning_rate: 0.0500
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0023 - root_mean_squared_error: 0.0482 - val_loss: 0.1611 - val_root_mean_squared_error: 0.4014 - learning_rate: 0.0500
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.0029 - root_mean_squared_error: 0.0539 - val_loss: 0.1686 - val_root_mean_squared_error: 0.4106 - learning_rate: 0.0500
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0019 - root_mean_squared_error: 0.0436 - val_loss: 0.1896 - val_root_mean_squared_error: 0.4354 - learning_rate: 0.0500
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.0021 - root_mean_squared_error: 0.0458 - val_loss: 0.1910 - val_root_mean_squared_error: 0.4371 - learning_rate: 0.0500
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0023 - root_mean_squared_error: 0.0478 - val_loss: 0.1785 - val_root_mean_squared_error: 0.4225 - learning_rate: 0.0500
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0025 - root_mean_squared_error: 0.0496 - val_loss: 0.1677 - val_root_mean_squared_error: 0.4095 - learning_rate: 0.0500
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0024 - root_mean_squared_error: 0.0485 - val_loss: 0.1847 - val_root_mean_squared_error: 0.4298 - learning_rate: 0.0500
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0017 - root_mean_squared_error: 0.0410 - val_loss: 0.1959 - val_root_mean_squared_error: 0.4426 - learning_rate: 0.0500
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0020 - root_mean_squared_error: 0.0444 - val_loss: 0.1856 - val_root_mean_squared_error: 0.4308 - learning_rate: 0.0500
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0016 - root_mean_squared_error: 0.0397 - val_loss: 0.1730 - val_root_mean_squared_error: 0.4159 - learning_rate: 0.0500
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0021 - root_mean_squared_error: 0.0456 - val_loss: 0.1696 - val_root_mean_squared_error: 0.4119 - learning_rate: 0.0500
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0017 - root_mean_squared_error: 0.0414 - val_loss: 0.1757 - val_root_mean_squared_error: 0.4192 - learning_rate: 0.0500
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0014 - root_mean_squared_error: 0.0373 - val_loss: 0.1825 - val_root_mean_squared_error: 0.4271 - learning_rate: 0.0500
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0017 - root_mean_squared_error: 0.0413 - val_loss: 0.1814 - val_root_mean_squared_error: 0.4259 - learning_rate: 0.0500
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0013 - root_mean_squared_error: 0.0361 - val_loss: 0.1720 - val_root_mean_squared_error: 0.4147 - learning_rate: 0.0500
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0013 - root_mean_squared_error: 0.0366 - val_loss: 0.1664 - val_root_mean_squared_error: 0.4080 - learning_rate: 0.0500
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0014 - root_mean_squared_error: 0.0372 - val_loss: 0.1706 - val_root_mean_squared_error: 0.4131 - learning_rate: 0.0500
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0010 - root_mean_squared_error: 0.0317 - val_loss: 0.1725 - val_root_mean_squared_error: 0.4153 - learning_rate: 0.0500
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0014 - root_mean_squared_error: 0.0379 - val_loss: 0.1735 - val_root_mean_squared_error: 0.4166 - learning_rate: 0.0500
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0010 - root_mean_squared_error: 0.0323 - val_loss: 0.1655 - val_root_mean_squared_error: 0.4068 - learning_rate: 0.0500
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 9.7731e-04 - root_mean_squared_error: 0.0313 - val_loss: 0.1713 - val_root_mean_squared_error: 0.4138 - learning_rate: 0.0500
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 9.3276e-04 - root_mean_squared_error: 0.0305 - val_loss: 0.1718 - val_root_mean_squared_error: 0.4144 - learning_rate: 0.0500
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0011 - root_mean_squared_error: 0.0325 - val_loss: 0.1779 - val_root_mean_squared_error: 0.4218 - learning_rate: 0.0500
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 9.1073e-04 - root_mean_squared_error: 0.0302 - val_loss: 0.1758 - val_root_mean_squared_error: 0.4193 - learning_rate: 0.0500
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 0.0010 - root_mean_squared_error: 0.0324 - val_loss: 0.1725 - val_root_mean_squared_error: 0.4154 - learning_rate: 0.0500
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 9.6289e-04 - root_mean_squared_error: 0.0310 - val_loss: 0.1710 - val_root_mean_squared_error: 0.4135 - learning_rate: 0.0500
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 8.5837e-04 - root_mean_squared_error: 0.0293 - val_loss: 0.1723 - val_root_mean_squared_error: 0.4151 - learning_rate: 0.0500
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0012 - root_mean_squared_error: 0.0344 - val_loss: 0.1742 - val_root_mean_squared_error: 0.4174 - learning_rate: 0.0500
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0010 - root_mean_squared_error: 0.0321 - val_loss: 0.1729 - val_root_mean_squared_error: 0.4158 - learning_rate: 0.0500
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 8.5930e-04 - root_mean_squared_error: 0.0293 - val_loss: 0.1669 - val_root_mean_squared_error: 0.4085 - learning_rate: 0.0500
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 8.9680e-04 - root_mean_squared_error: 0.0299 - val_loss: 0.1659 - val_root_mean_squared_error: 0.4073 - learning_rate: 0.0500
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0010 - root_mean_squared_error: 0.0318 - val_loss: 0.1709 - val_root_mean_squared_error: 0.4134 - learning_rate: 0.0500
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 7.6765e-04 - root_mean_squared_error: 0.0277 - val_loss: 0.1751 - val_root_mean_squared_error: 0.4185 - learning_rate: 0.0500
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0012 - root_mean_squared_error: 0.0341 - val_loss: 0.1728 - val_root_mean_squared_error: 0.4157 - learning_rate: 0.0500
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 8.7953e-04 - root_mean_squared_error: 0.0297 - val_loss: 0.1677 - val_root_mean_squared_error: 0.4095 - learning_rate: 0.0500
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 9.4490e-04 - root_mean_squared_error: 0.0307 - val_loss: 0.1779 - val_root_mean_squared_error: 0.4218 - learning_rate: 0.0500
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 8.7948e-04 - root_mean_squared_error: 0.0297 - val_loss: 0.1863 - val_root_mean_squared_error: 0.4316 - learning_rate: 0.0500
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0012 - root_mean_squared_error: 0.0341 - val_loss: 0.1791 - val_root_mean_squared_error: 0.4232 - learning_rate: 0.0500
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 9.0505e-04 - root_mean_squared_error: 0.0301 - val_loss: 0.1606 - val_root_mean_squared_error: 0.4008 - learning_rate: 0.0500
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0014 - root_mean_squared_error: 0.0370 - val_loss: 0.1707 - val_root_mean_squared_error: 0.4132 - learning_rate: 0.0500
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 8.1109e-04 - root_mean_squared_error: 0.0285 - val_loss: 0.1908 - val_root_mean_squared_error: 0.4368 - learning_rate: 0.0500
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0010 - root_mean_squared_error: 0.0321 - val_loss: 0.1830 - val_root_mean_squared_error: 0.4278 - learning_rate: 0.0500
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 8.4074e-04 - root_mean_squared_error: 0.0290 - val_loss: 0.1698 - val_root_mean_squared_error: 0.4121 - learning_rate: 0.0500
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 9.5434e-04 - root_mean_squared_error: 0.0309 - val_loss: 0.1727 - val_root_mean_squared_error: 0.4156 - learning_rate: 0.0500
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 7.1544e-04 - root_mean_squared_error: 0.0267 - val_loss: 0.1858 - val_root_mean_squared_error: 0.4311 - learning_rate: 0.0500
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 9.1468e-04 - root_mean_squared_error: 0.0302 - val_loss: 0.1803 - val_root_mean_squared_error: 0.4246 - learning_rate: 0.0500
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 7.1816e-04 - root_mean_squared_error: 0.0268 - val_loss: 0.1632 - val_root_mean_squared_error: 0.4040 - learning_rate: 0.0500
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0014 - root_mean_squared_error: 0.0376 - val_loss: 0.1694 - val_root_mean_squared_error: 0.4116 - learning_rate: 0.0500
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 7.4214e-04 - root_mean_squared_error: 0.0272 - val_loss: 0.1916 - val_root_mean_squared_error: 0.4378 - learning_rate: 0.0500
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0012 - root_mean_squared_error: 0.0343 - val_loss: 0.1952 - val_root_mean_squared_error: 0.4418 - learning_rate: 0.0500
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0014 - root_mean_squared_error: 0.0375 - val_loss: 0.1744 - val_root_mean_squared_error: 0.4176 - learning_rate: 0.0500
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 6.1676e-04 - root_mean_squared_error: 0.0248 - val_loss: 0.1598 - val_root_mean_squared_error: 0.3998 - learning_rate: 0.0500
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0016 - root_mean_squared_error: 0.0406 - val_loss: 0.1744 - val_root_mean_squared_error: 0.4176 - learning_rate: 0.0500
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 6.3719e-04 - root_mean_squared_error: 0.0252 - val_loss: 0.1940 - val_root_mean_squared_error: 0.4405 - learning_rate: 0.0500
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0012 - root_mean_squared_error: 0.0352 - val_loss: 0.1916 - val_root_mean_squared_error: 0.4377 - learning_rate: 0.0500
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0012 - root_mean_squared_error: 0.0346 - val_loss: 0.1729 - val_root_mean_squared_error: 0.4158 - learning_rate: 0.0500
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 8.1800e-04 - root_mean_squared_error: 0.0286 - val_loss: 0.1588 - val_root_mean_squared_error: 0.3984 - learning_rate: 0.0500
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0012 - root_mean_squared_error: 0.0351 - val_loss: 0.1660 - val_root_mean_squared_error: 0.4074 - learning_rate: 0.0500
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 7.2958e-04 - root_mean_squared_error: 0.0270 - val_loss: 0.1812 - val_root_mean_squared_error: 0.4257 - learning_rate: 0.0500
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 8.1974e-04 - root_mean_squared_error: 0.0286 - val_loss: 0.1822 - val_root_mean_squared_error: 0.4268 - learning_rate: 0.0500
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.0010 - root_mean_squared_error: 0.0321 - val_loss: 0.1675 - val_root_mean_squared_error: 0.4092 - learning_rate: 0.0500
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 5.9059e-04 - root_mean_squared_error: 0.0243 - val_loss: 0.1611 - val_root_mean_squared_error: 0.4014 - learning_rate: 0.0500
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 9.6006e-04 - root_mean_squared_error: 0.0310 - val_loss: 0.1719 - val_root_mean_squared_error: 0.4147 - learning_rate: 0.0500
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 5.2796e-04 - root_mean_squared_error: 0.0230 - val_loss: 0.1826 - val_root_mean_squared_error: 0.4273 - learning_rate: 0.0500
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 8.6827e-04 - root_mean_squared_error: 0.0295 - val_loss: 0.1785 - val_root_mean_squared_error: 0.4225 - learning_rate: 0.0500
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 7.1578e-04 - root_mean_squared_error: 0.0268 - val_loss: 0.1683 - val_root_mean_squared_error: 0.4102 - learning_rate: 0.0500
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 7.9988e-04 - root_mean_squared_error: 0.0283 - val_loss: 0.1654 - val_root_mean_squared_error: 0.4067 - learning_rate: 0.0500
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 7.6428e-04 - root_mean_squared_error: 0.0276 - val_loss: 0.1740 - val_root_mean_squared_error: 0.4172 - learning_rate: 0.0500
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 6.2316e-04 - root_mean_squared_error: 0.0250 - val_loss: 0.1741 - val_root_mean_squared_error: 0.4172 - learning_rate: 5.0000e-04
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 4.6624e-04 - root_mean_squared_error: 0.0216 - val_loss: 0.1740 - val_root_mean_squared_error: 0.4172 - learning_rate: 5.0000e-04
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 4.6032e-04 - root_mean_squared_error: 0.0215 - val_loss: 0.1740 - val_root_mean_squared_error: 0.4171 - learning_rate: 5.0000e-04
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 6.6442e-04 - root_mean_squared_error: 0.0258 - val_loss: 0.1739 - val_root_mean_squared_error: 0.4170 - learning_rate: 5.0000e-04
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 5.1504e-04 - root_mean_squared_error: 0.0227 - val_loss: 0.1738 - val_root_mean_squared_error: 0.4169 - learning_rate: 5.0000e-04
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 4.9408e-04 - root_mean_squared_error: 0.0222 - val_loss: 0.1737 - val_root_mean_squared_error: 0.4168 - learning_rate: 5.0000e-04
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 8.0217e-04 - root_mean_squared_error: 0.0283 - val_loss: 0.1737 - val_root_mean_squared_error: 0.4167 - learning_rate: 5.0000e-04
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 6.4510e-04 - root_mean_squared_error: 0.0254 - val_loss: 0.1736 - val_root_mean_squared_error: 0.4166 - learning_rate: 5.0000e-04
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 4.9394e-04 - root_mean_squared_error: 0.0222 - val_loss: 0.1735 - val_root_mean_squared_error: 0.4165 - learning_rate: 5.0000e-04
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 5.6158e-04 - root_mean_squared_error: 0.0237 - val_loss: 0.1734 - val_root_mean_squared_error: 0.4164 - learning_rate: 5.0000e-04
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 7.5350e-04 - root_mean_squared_error: 0.0275 - val_loss: 0.1733 - val_root_mean_squared_error: 0.4163 - learning_rate: 5.0000e-04
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 5.6959e-04 - root_mean_squared_error: 0.0239 - val_loss: 0.1731 - val_root_mean_squared_error: 0.4161 - learning_rate: 5.0000e-04
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 7.1117e-04 - root_mean_squared_error: 0.0267 - val_loss: 0.1730 - val_root_mean_squared_error: 0.4160 - learning_rate: 5.0000e-04
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 5.4578e-04 - root_mean_squared_error: 0.0234 - val_loss: 0.1729 - val_root_mean_squared_error: 0.4158 - learning_rate: 5.0000e-04
# Epoch 116/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 6.1535e-04 - root_mean_squared_error: 0.0248 - val_loss: 0.1728 - val_root_mean_squared_error: 0.4156 - learning_rate: 5.0000e-04
# Epoch 117/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 4.7377e-04 - root_mean_squared_error: 0.0218 - val_loss: 0.1726 - val_root_mean_squared_error: 0.4155 - learning_rate: 5.0000e-04
# Epoch 118/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 6.4969e-04 - root_mean_squared_error: 0.0255 - val_loss: 0.1725 - val_root_mean_squared_error: 0.4153 - learning_rate: 5.0000e-04
# Epoch 119/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 6.4224e-04 - root_mean_squared_error: 0.0253 - val_loss: 0.1723 - val_root_mean_squared_error: 0.4151 - learning_rate: 5.0000e-04
# Epoch 120/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 6.9326e-04 - root_mean_squared_error: 0.0263 - val_loss: 0.1721 - val_root_mean_squared_error: 0.4149 - learning_rate: 5.0000e-04
# Epoch 121/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 5.6085e-04 - root_mean_squared_error: 0.0237 - val_loss: 0.1720 - val_root_mean_squared_error: 0.4147 - learning_rate: 5.0000e-04
# Epoch 122/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 4.8394e-04 - root_mean_squared_error: 0.0220 - val_loss: 0.1718 - val_root_mean_squared_error: 0.4145 - learning_rate: 5.0000e-04
# Epoch 123/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 4.4222e-04 - root_mean_squared_error: 0.0210 - val_loss: 0.1716 - val_root_mean_squared_error: 0.4142 - learning_rate: 5.0000e-04
# Epoch 124/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 5.3416e-04 - root_mean_squared_error: 0.0231 - val_loss: 0.1714 - val_root_mean_squared_error: 0.4140 - learning_rate: 5.0000e-04
# Epoch 125/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 5.2288e-04 - root_mean_squared_error: 0.0229 - val_loss: 0.1712 - val_root_mean_squared_error: 0.4138 - learning_rate: 5.0000e-04
# Epoch 126/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 4.1994e-04 - root_mean_squared_error: 0.0205 - val_loss: 0.1711 - val_root_mean_squared_error: 0.4137 - learning_rate: 5.0000e-04
# Epoch 127/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 4.8825e-04 - root_mean_squared_error: 0.0221 - val_loss: 0.1710 - val_root_mean_squared_error: 0.4135 - learning_rate: 5.0000e-04
# Epoch 128/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 4.8584e-04 - root_mean_squared_error: 0.0220 - val_loss: 0.1709 - val_root_mean_squared_error: 0.4134 - learning_rate: 5.0000e-04
# Epoch 129/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 5.3037e-04 - root_mean_squared_error: 0.0230 - val_loss: 0.1708 - val_root_mean_squared_error: 0.4133 - learning_rate: 5.0000e-04
# Epoch 130/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 5.3987e-04 - root_mean_squared_error: 0.0232 - val_loss: 0.1708 - val_root_mean_squared_error: 0.4132 - learning_rate: 5.0000e-04
# Epoch 131/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 4.4066e-04 - root_mean_squared_error: 0.0210 - val_loss: 0.1707 - val_root_mean_squared_error: 0.4132 - learning_rate: 5.0000e-04
# Epoch 132/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 4.7659e-04 - root_mean_squared_error: 0.0218 - val_loss: 0.1706 - val_root_mean_squared_error: 0.4131 - learning_rate: 5.0000e-04
# Epoch 133/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 5.8141e-04 - root_mean_squared_error: 0.0241 - val_loss: 0.1706 - val_root_mean_squared_error: 0.4130 - learning_rate: 5.0000e-04
# Epoch 134/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 5.2382e-04 - root_mean_squared_error: 0.0229 - val_loss: 0.1705 - val_root_mean_squared_error: 0.4129 - learning_rate: 5.0000e-04
# Epoch 135/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 4.1719e-04 - root_mean_squared_error: 0.0204 - val_loss: 0.1704 - val_root_mean_squared_error: 0.4128 - learning_rate: 5.0000e-04
# Epoch 136/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 3.9413e-04 - root_mean_squared_error: 0.0199 - val_loss: 0.1703 - val_root_mean_squared_error: 0.4127 - learning_rate: 5.0000e-04
# Epoch 137/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 5.3842e-04 - root_mean_squared_error: 0.0232 - val_loss: 0.1702 - val_root_mean_squared_error: 0.4125 - learning_rate: 5.0000e-04
# Epoch 138/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 5.3577e-04 - root_mean_squared_error: 0.0231 - val_loss: 0.1701 - val_root_mean_squared_error: 0.4125 - learning_rate: 5.0000e-04
# Epoch 139/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 5.4880e-04 - root_mean_squared_error: 0.0234 - val_loss: 0.1700 - val_root_mean_squared_error: 0.4124 - learning_rate: 5.0000e-04
# Epoch 140/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 6.2903e-04 - root_mean_squared_error: 0.0251 - val_loss: 0.1700 - val_root_mean_squared_error: 0.4123 - learning_rate: 5.0000e-04
# Epoch 141/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 4.5886e-04 - root_mean_squared_error: 0.0214 - val_loss: 0.1699 - val_root_mean_squared_error: 0.4122 - learning_rate: 5.0000e-04
# Epoch 142/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 4.5662e-04 - root_mean_squared_error: 0.0214 - val_loss: 0.1699 - val_root_mean_squared_error: 0.4122 - learning_rate: 5.0000e-04
# Epoch 143/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 5.3978e-04 - root_mean_squared_error: 0.0232 - val_loss: 0.1698 - val_root_mean_squared_error: 0.4121 - learning_rate: 5.0000e-04
# Epoch 144/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 5.1239e-04 - root_mean_squared_error: 0.0226 - val_loss: 0.1698 - val_root_mean_squared_error: 0.4120 - learning_rate: 5.0000e-04
# Epoch 145/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - loss: 3.8555e-04 - root_mean_squared_error: 0.0196 - val_loss: 0.1697 - val_root_mean_squared_error: 0.4119 - learning_rate: 5.0000e-04
# Epoch 146/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - loss: 6.0343e-04 - root_mean_squared_error: 0.0246 - val_loss: 0.1696 - val_root_mean_squared_error: 0.4118 - learning_rate: 5.0000e-04
# Epoch 147/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - loss: 5.5161e-04 - root_mean_squared_error: 0.0235 - val_loss: 0.1696 - val_root_mean_squared_error: 0.4118 - learning_rate: 5.0000e-04
# Epoch 148/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - loss: 3.8609e-04 - root_mean_squared_error: 0.0196 - val_loss: 0.1696 - val_root_mean_squared_error: 0.4118 - learning_rate: 5.0000e-04
# Epoch 149/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step - loss: 6.1473e-04 - root_mean_squared_error: 0.0248 - val_loss: 0.1696 - val_root_mean_squared_error: 0.4118 - learning_rate: 5.0000e-04
# Epoch 150/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 6.0306e-04 - root_mean_squared_error: 0.0246 - val_loss: 0.1696 - val_root_mean_squared_error: 0.4118 - learning_rate: 5.0000e-04
# Epoch 151/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step - loss: 4.1204e-04 - root_mean_squared_error: 0.0203 - val_loss: 0.1696 - val_root_mean_squared_error: 0.4118 - learning_rate: 5.0000e-04
# Epoch 152/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - loss: 4.7911e-04 - root_mean_squared_error: 0.0219 - val_loss: 0.1695 - val_root_mean_squared_error: 0.4117 - learning_rate: 5.0000e-04
# Epoch 153/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 4.3131e-04 - root_mean_squared_error: 0.0208 - val_loss: 0.1695 - val_root_mean_squared_error: 0.4117 - learning_rate: 5.0000e-04
# Epoch 154/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - loss: 5.2424e-04 - root_mean_squared_error: 0.0229 - val_loss: 0.1695 - val_root_mean_squared_error: 0.4117 - learning_rate: 5.0000e-04
# Epoch 155/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 5.3864e-04 - root_mean_squared_error: 0.0232 - val_loss: 0.1694 - val_root_mean_squared_error: 0.4116 - learning_rate: 5.0000e-04
# Epoch 156/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 5.8462e-04 - root_mean_squared_error: 0.0242 - val_loss: 0.1694 - val_root_mean_squared_error: 0.4115 - learning_rate: 5.0000e-04
# Epoch 157/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 5.2100e-04 - root_mean_squared_error: 0.0228 - val_loss: 0.1693 - val_root_mean_squared_error: 0.4115 - learning_rate: 5.0000e-04
# Epoch 158/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - loss: 5.0019e-04 - root_mean_squared_error: 0.0224 - val_loss: 0.1692 - val_root_mean_squared_error: 0.4114 - learning_rate: 5.0000e-04
# Epoch 159/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - loss: 5.1940e-04 - root_mean_squared_error: 0.0228 - val_loss: 0.1691 - val_root_mean_squared_error: 0.4112 - learning_rate: 5.0000e-04
# Epoch 160/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 3.6169e-04 - root_mean_squared_error: 0.0190 - val_loss: 0.1690 - val_root_mean_squared_error: 0.4111 - learning_rate: 5.0000e-04
# Epoch 161/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 5.0424e-04 - root_mean_squared_error: 0.0225 - val_loss: 0.1690 - val_root_mean_squared_error: 0.4111 - learning_rate: 5.0000e-04
# Epoch 162/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 5.7681e-04 - root_mean_squared_error: 0.0240 - val_loss: 0.1689 - val_root_mean_squared_error: 0.4110 - learning_rate: 5.0000e-04
# Epoch 163/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - loss: 5.8175e-04 - root_mean_squared_error: 0.0241 - val_loss: 0.1689 - val_root_mean_squared_error: 0.4109 - learning_rate: 5.0000e-04
# Epoch 164/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - loss: 7.2782e-04 - root_mean_squared_error: 0.0270 - val_loss: 0.1688 - val_root_mean_squared_error: 0.4109 - learning_rate: 5.0000e-04
# Epoch 165/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 4.6328e-04 - root_mean_squared_error: 0.0215 - val_loss: 0.1687 - val_root_mean_squared_error: 0.4108 - learning_rate: 5.0000e-04
# Epoch 166/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - loss: 5.4505e-04 - root_mean_squared_error: 0.0233 - val_loss: 0.1686 - val_root_mean_squared_error: 0.4107 - learning_rate: 5.0000e-04
# Epoch 167/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - loss: 4.8650e-04 - root_mean_squared_error: 0.0221 - val_loss: 0.1686 - val_root_mean_squared_error: 0.4106 - learning_rate: 5.0000e-04
# Epoch 168/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - loss: 5.0554e-04 - root_mean_squared_error: 0.0225 - val_loss: 0.1685 - val_root_mean_squared_error: 0.4105 - learning_rate: 5.0000e-04
# Epoch 169/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - loss: 4.7617e-04 - root_mean_squared_error: 0.0218 - val_loss: 0.1684 - val_root_mean_squared_error: 0.4103 - learning_rate: 5.0000e-04
# Epoch 170/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - loss: 6.0582e-04 - root_mean_squared_error: 0.0246 - val_loss: 0.1683 - val_root_mean_squared_error: 0.4102 - learning_rate: 5.0000e-04
# Epoch 171/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - loss: 5.2853e-04 - root_mean_squared_error: 0.0230 - val_loss: 0.1682 - val_root_mean_squared_error: 0.4102 - learning_rate: 5.0000e-04
# Epoch 172/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - loss: 4.9869e-04 - root_mean_squared_error: 0.0223 - val_loss: 0.1682 - val_root_mean_squared_error: 0.4101 - learning_rate: 5.0000e-04
# Epoch 173/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step - loss: 5.6461e-04 - root_mean_squared_error: 0.0238 - val_loss: 0.1681 - val_root_mean_squared_error: 0.4100 - learning_rate: 5.0000e-04
# Epoch 174/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 6.3323e-04 - root_mean_squared_error: 0.0252 - val_loss: 0.1681 - val_root_mean_squared_error: 0.4100 - learning_rate: 5.0000e-04
# Epoch 175/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 6.7979e-04 - root_mean_squared_error: 0.0261 - val_loss: 0.1680 - val_root_mean_squared_error: 0.4099 - learning_rate: 5.0000e-04
# Epoch 176/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 4.8908e-04 - root_mean_squared_error: 0.0221 - val_loss: 0.1679 - val_root_mean_squared_error: 0.4098 - learning_rate: 5.0000e-04
# Epoch 177/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 5.0856e-04 - root_mean_squared_error: 0.0226 - val_loss: 0.1678 - val_root_mean_squared_error: 0.4097 - learning_rate: 5.0000e-04
# Epoch 178/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 6.0218e-04 - root_mean_squared_error: 0.0245 - val_loss: 0.1677 - val_root_mean_squared_error: 0.4095 - learning_rate: 5.0000e-04
# Epoch 179/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 4.5492e-04 - root_mean_squared_error: 0.0213 - val_loss: 0.1675 - val_root_mean_squared_error: 0.4093 - learning_rate: 5.0000e-04
# Epoch 180/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 5.4923e-04 - root_mean_squared_error: 0.0234 - val_loss: 0.1674 - val_root_mean_squared_error: 0.4092 - learning_rate: 5.0000e-04
# Epoch 181/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 6.0250e-04 - root_mean_squared_error: 0.0245 - val_loss: 0.1674 - val_root_mean_squared_error: 0.4091 - learning_rate: 5.0000e-04
# Epoch 182/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 4.9675e-04 - root_mean_squared_error: 0.0223 - val_loss: 0.1673 - val_root_mean_squared_error: 0.4090 - learning_rate: 5.0000e-05
# Epoch 183/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 6.5755e-04 - root_mean_squared_error: 0.0256 - val_loss: 0.1672 - val_root_mean_squared_error: 0.4089 - learning_rate: 5.0000e-05
# Epoch 184/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 5.0516e-04 - root_mean_squared_error: 0.0225 - val_loss: 0.1671 - val_root_mean_squared_error: 0.4088 - learning_rate: 5.0000e-05
# Epoch 185/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 4.3066e-04 - root_mean_squared_error: 0.0208 - val_loss: 0.1671 - val_root_mean_squared_error: 0.4087 - learning_rate: 5.0000e-05
# Epoch 186/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 3.6135e-04 - root_mean_squared_error: 0.0190 - val_loss: 0.1670 - val_root_mean_squared_error: 0.4086 - learning_rate: 5.0000e-05
# Epoch 187/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 6.6401e-04 - root_mean_squared_error: 0.0258 - val_loss: 0.1669 - val_root_mean_squared_error: 0.4086 - learning_rate: 5.0000e-05
# Epoch 188/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 5.0184e-04 - root_mean_squared_error: 0.0224 - val_loss: 0.1669 - val_root_mean_squared_error: 0.4085 - learning_rate: 5.0000e-05
# Epoch 189/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 5.8120e-04 - root_mean_squared_error: 0.0241 - val_loss: 0.1668 - val_root_mean_squared_error: 0.4084 - learning_rate: 5.0000e-05
# Epoch 190/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 4.4661e-04 - root_mean_squared_error: 0.0211 - val_loss: 0.1667 - val_root_mean_squared_error: 0.4083 - learning_rate: 5.0000e-05
# Epoch 191/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 5.0951e-04 - root_mean_squared_error: 0.0226 - val_loss: 0.1666 - val_root_mean_squared_error: 0.4082 - learning_rate: 5.0000e-05
# Epoch 192/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 6.7767e-04 - root_mean_squared_error: 0.0260 - val_loss: 0.1666 - val_root_mean_squared_error: 0.4081 - learning_rate: 1.0000e-05
# Epoch 193/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 4.4317e-04 - root_mean_squared_error: 0.0211 - val_loss: 0.1665 - val_root_mean_squared_error: 0.4080 - learning_rate: 1.0000e-05
# Epoch 194/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 5.2534e-04 - root_mean_squared_error: 0.0229 - val_loss: 0.1664 - val_root_mean_squared_error: 0.4079 - learning_rate: 1.0000e-05
# Epoch 195/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 4.7331e-04 - root_mean_squared_error: 0.0218 - val_loss: 0.1663 - val_root_mean_squared_error: 0.4078 - learning_rate: 1.0000e-05
# Epoch 196/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 4.8423e-04 - root_mean_squared_error: 0.0220 - val_loss: 0.1662 - val_root_mean_squared_error: 0.4077 - learning_rate: 1.0000e-05
# Epoch 197/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 3.9757e-04 - root_mean_squared_error: 0.0199 - val_loss: 0.1661 - val_root_mean_squared_error: 0.4076 - learning_rate: 1.0000e-05
# Epoch 198/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 6.0165e-04 - root_mean_squared_error: 0.0245 - val_loss: 0.1660 - val_root_mean_squared_error: 0.4075 - learning_rate: 1.0000e-05
# Epoch 199/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 6.4808e-04 - root_mean_squared_error: 0.0255 - val_loss: 0.1660 - val_root_mean_squared_error: 0.4074 - learning_rate: 1.0000e-05
# Epoch 200/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 6.0285e-04 - root_mean_squared_error: 0.0246 - val_loss: 0.1659 - val_root_mean_squared_error: 0.4073 - learning_rate: 1.0000e-05

# %%
# Crear la secuencia de entrada inicial con la forma correcta (1, sequence_length, features)
input_sequence = Test_X[-1].reshape(1, Test_X.shape[1], 1)  # Cambia el 1 por la cantidad de características si es diferente

# %%
epochs = range(1, len(H.history["loss"]) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs, H.history["root_mean_squared_error"], label="Training RMSE")
plt.plot(epochs, H.history["val_root_mean_squared_error"], label="Validation RMSE")
plt.xlabel("Epochs")
plt.ylabel("Root Mean Squared Error (RMSE)")
plt.title("Training and Validation RMSE Over Epochs")
plt.legend()
plt.show()

# %%
# Realizar predicciones con el modelo LSTM en los datos de prueba
scaled_predictions = my_LSTM_model.predict(Test_X)

# Reescalar los datos para devolverlos al rango original
# Invertimos la escala del predictor
scaled_predictions_reshaped = scaled_predictions.reshape(-1, 1)
Test_Y_reshaped = Test_Y.reshape(-1, 1)

# Invertimos la escala
original_predictions = scaler.inverse_transform(scaled_predictions_reshaped)
original_test_Y = scaler.inverse_transform(Test_Y_reshaped)

# Calcular el RMSE entre las predicciones y los valores reales
rmse = np.sqrt(mean_squared_error(original_test_Y, original_predictions))
print(f"LSTM Model RMSE on Scaled Data: {rmse:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# LSTM Model RMSE on Scaled Data: 58.6412

# %% [markdown]
# # ¿Consideras que el escalamiento de los datos ayude a obtener mejores predicciones? Justifica tu respuesta.

# %% [markdown]
# El escalamiento de los datos puede ser una herramienta útil para mejorar la precisión y estabilidad de algunos modelos predictivos, pero su efectividad depende en gran medida del tipo de modelo que se esté utilizando y de las características inherentes de los datos. En términos generales, el escalamiento transforma los datos a una escala común, típicamente entre 0 y 1, lo que puede ayudar a ciertos algoritmos de aprendizaje automático, como redes neuronales y modelos basados en gradiente, a converger más rápido y evitar problemas de cálculo con valores grandes o variables en escalas diferentes.
#
# En el caso de los modelos de series temporales, el impacto del escalamiento es variado. Por ejemplo, en un modelo basado en redes neuronales como LSTM, el escalamiento de los datos puede ser crucial. Dado que los LSTM utilizan multiplicaciones y sumas sucesivas a lo largo de la secuencia, trabajar con datos no escalados o con grandes diferencias en magnitudes puede llevar a que el modelo tenga dificultades para encontrar patrones consistentes y que las actualizaciones de los pesos sean ineficaces. En estos casos, el escalamiento ayuda a que el modelo tenga una representación más uniforme de las entradas, facilitando el aprendizaje de los patrones en la serie temporal y, en última instancia, mejorando la precisión de las predicciones.
#
# Por otro lado, en modelos estadísticos como ARIMA y Prophet, el impacto del escalamiento es menos directo. ARIMA, que es un modelo lineal, y Prophet, que es una herramienta basada en descomposición de series temporales, suelen funcionar bien con datos no escalados, ya que su estructura y optimización no dependen tanto de la escala de los valores. En nuestro trabajo con Prophet, el modelo ha funcionado correctamente tanto en datos originales como en datos escalados, pero el escalamiento no necesariamente ha demostrado ser determinante en la mejora de las predicciones. No obstante, el escalamiento puede ser útil si estamos trabajando con múltiples series temporales con diferentes unidades o si queremos uniformidad en el procesamiento de datos.
#
# Para el modelo ingenuo, el escalamiento no aporta ninguna ventaja significativa en términos de precisión, ya que este tipo de modelo simplemente utiliza el último valor observado como predicción para el siguiente punto. El modelo ingenuo no tiene un proceso de optimización que se beneficie de trabajar en una escala específica.
#
# En conclusión, el escalamiento es más relevante en modelos complejos de aprendizaje automático, como las redes neuronales, que requieren que los datos estén en un rango uniforme para optimizar sus pesos de manera efectiva. En cambio, en modelos estadísticos tradicionales como ARIMA y Prophet, el escalamiento no es estrictamente necesario y, en algunos casos, puede incluso agregar una capa de procesamiento adicional sin un beneficio claro en la precisión. Por lo tanto, es importante evaluar el tipo de modelo y la naturaleza de los datos antes de decidir si el escalamiento de datos será realmente beneficioso para mejorar las predicciones.

# %% [markdown]
# # Conclusión final (Personal)

# %% [markdown]
# Durante el desarrollo de esta actividad, fue evidente la importancia de explorar diferentes enfoques y técnicas de modelado para realizar predicciones de series de tiempo. Cada uno de los modelos utilizados, desde el modelo ingenuo hasta los más complejos como ARIMA y Prophet, presentó sus propias ventajas y limitaciones. Al comparar los resultados, se puede ver cómo la precisión y el rendimiento de cada modelo varían dependiendo de la complejidad y la capacidad para capturar patrones en los datos históricos. Esto ilustra un punto fundamental en la ciencia de datos: no existe un único modelo perfecto, y a menudo es necesario probar varias aproximaciones para determinar cuál se ajusta mejor a los datos y al contexto de la aplicación.
#
# Uno de los aspectos clave fue la experimentación con el escalado de datos. Al escalar los datos al intervalo [0,1], se observó que algunos modelos, en especial los que implican cálculos matemáticos complejos como ARIMA y Prophet, podían beneficiarse en términos de estabilidad y convergencia. El escalado ayuda a normalizar la magnitud de los datos y reducir posibles efectos de valores extremos, lo cual es especialmente útil en modelos sensibles a estos cambios. Sin embargo, también se observó que el impacto del escalado depende en gran medida del tipo de modelo y de la variabilidad de la serie de tiempo. En algunos casos, el escalado no necesariamente produjo una mejora significativa en el error de predicción, pero ayudó a que los modelos fueran más consistentes.
#
# Además, la actividad me permitió reflexionar sobre la importancia del análisis de errores, específicamente el RMSE (Root Mean Square Error) relativo al promedio y al rango de los datos. Esta métrica proporcionó una perspectiva más completa sobre el desempeño del modelo en relación con la escala de los datos. En lugar de solo evaluar el RMSE en términos absolutos, el RMSE relativo nos da una idea de qué tan significativo es el error en comparación con los valores típicos de la serie. Esto es especialmente útil para interpretar la calidad de las predicciones y comprender si los errores son aceptables dentro del contexto de la serie de tiempo analizada.
#
# Finalmente, uno de los desafíos más destacados fue la implementación y ajuste de los modelos avanzados, especialmente Prophet y ARIMA. Ambos modelos requieren una buena comprensión de sus parámetros para obtener el mejor rendimiento, lo cual enfatiza la necesidad de una buena base teórica y práctica en la selección y ajuste de modelos. Prophet, por ejemplo, demostró ser muy útil para series con patrones de estacionalidad y tendencia marcados, mientras que ARIMA mostró su fortaleza en datos más estables y sin estacionalidad fuerte.
#
# En conclusión, esta actividad me ha permitido ver de manera integral el proceso de modelado de series de tiempo, desde la preparación de los datos hasta la evaluación de los resultados. La experimentación con diferentes modelos y técnicas de escalado refuerza la idea de que el proceso de predicción es iterativo y depende en gran medida de una cuidadosa evaluación y comparación de resultados. Esto ha sido una experiencia enriquecedora que subraya la importancia de ser flexible y crítico en la selección de modelos y de considerar siempre el contexto y la naturaleza de los datos para tomar decisiones informadas.
